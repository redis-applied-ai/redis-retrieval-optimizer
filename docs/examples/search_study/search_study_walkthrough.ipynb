# %% [markdown]
# # Search study
#
# Let's say you have an existing Redis database with a search index seeded. You may wish to quickly test different search method against the existing index without having to recreate data and/or recreate the index. This demo will walk you though how to set this up and get going.
#
# # Installation

# %%
# %pip install redis-retrieval-optimizer

# %%
import redis_retrieval_optimizer

redis_retrieval_optimizer.__version__
# Out:
# '0.4.1'

# %% [markdown]
# # Load data
#
# We will load our custom car dataset for this example.

# %%
import json

with open('../resources/cars/car_corpus.json', 'r') as f:
    corpus = json.load(f)

with open('../resources/cars/car_queries.json', 'r') as f:
    queries = json.load(f)

with open('../resources/cars/car_qrels.json', 'r') as f:
    qrels = json.load(f)

# %% [markdown]
# # Create the index with redisvl
#
# For the search_study we are assuming that the search index already exists. The cell below will create a Redis search index and populate it with our test data for example purposes but is assumed with a search study is populated and running within your data.
#
# Note: the demo assumes you have a instance of redis running on localhost:6379. If this is not the case, update the redis_url to direct to your running instance or start a local instance with the following command.
#
# `docker run -d --name redis-stack-server -p 6379:6379 redis/redis-stack-server:latest`

# %%
# assuming you have a redis instance running on localhost:6379
redis_url = "redis://localhost:6379"

# %%
from redisvl.index import SearchIndex
from redisvl.utils.vectorize import HFTextVectorizer

emb_model = HFTextVectorizer()

# define schema
car_schema = {
    "index": {
        "name": "cars",
        "prefix": "cars"
    },
    "fields": [
        {"name": "item_id", "type": "tag"},
        {"name": "text", "type": "text"},
        {"name": "make", "type": "tag"},
        {"name": "model", "type": "tag"},
        {
            "name": "vector",
            "type": "vector",
            "attrs": {
                "dims": 768,
                "distance_metric": "cosine",
                "algorithm": "FLAT",
                "datatype": "float32"
            },
        },
    ]
}

# create index
index = SearchIndex.from_dict(car_schema, redis_url=redis_url)
index.create(overwrite=True)

embeddings = emb_model.embed_many([c["text"] for c in corpus], as_buffer=True)

# vectorize corpus data
corpus_data = [
    {
        "text": c["text"],
        "item_id": c["item_id"],
        "make": c["query_metadata"]["make"],
        "model": c["query_metadata"]["model"],
        "vector": embeddings[i]
    }
    for i, c in enumerate(corpus)
]

index.load(corpus_data)
# Out:
# 15:37:06 sentence_transformers.SentenceTransformer INFO   Use pytorch device_name: mps
# 15:37:06 sentence_transformers.SentenceTransformer INFO   Load pretrained SentenceTransformer: sentence-transformers/all-mpnet-base-v2
# ['cars:01K3KY4XKBMD7B5VWDYMBPT8CV',
#  'cars:01K3KY4XKBJBADHWYSSVKYXFA3',
#  'cars:01K3KY4XKBAFQXKJA8D24XTN4V',
#  'cars:01K3KY4XKB4YK5J8M2BJ3RG2ZZ',
#  'cars:01K3KY4XKBJ9BEN9KA5MY5B17F',
#  'cars:01K3KY4XKB1YN12H0E8RYF908V',
#  'cars:01K3KY4XKBBCQRKZF2WKN35N1M',
#  'cars:01K3KY4XKBCFNP86PB1X20BKP6',
#  'cars:01K3KY4XKBB1TW18MW7FXQHPGV',
#  'cars:01K3KY4XKBNSAD3KQKWHY8ZEZV',
#  'cars:01K3KY4XKBZASFPS1QAFT8AB9M',
#  'cars:01K3KY4XKB6WS6EXC6D29HGB2B',
#  'cars:01K3KY4XKBG7BDE2W5096JCPV1',
#  'cars:01K3KY4XKBTJPHE8DJJDZ0F25N',
#  'cars:01K3KY4XKB5G1J1HVVZNEHMD1G',
#  'cars:01K3KY4XKB0G2NJSFABD1C0V2V',
#  'cars:01K3KY4XKBE15Y724Q1MFRT1JD',
#  'cars:01K3KY4XKB9BET7ZPS9PWS9FAM',
#  'cars:01K3KY4XKBKK7N32WVSACBRDAH',
#  'cars:01K3KY4XKB8WN4FZQHYN7N5M3Y',
#  'cars:01K3KY4XKB3NFV4KCC3ZR9S1W3',
#  'cars:01K3KY4XKBS0HT7SQPHKCZJ7K1',
#  'cars:01K3KY4XKB9YAVWSK2EHPKCMJW',
#  'cars:01K3KY4XKB26NXA6V8NY5DFS28',
#  'cars:01K3KY4XKBKRQFSYB64XT263TZ',
#  'cars:01K3KY4XKBA1G1N5GV81TQBG4V',
#  'cars:01K3KY4XKBAZ9F12ANSMDMXY89',
#  'cars:01K3KY4XKBHR8EYYS9S8KWZXR9',
#  'cars:01K3KY4XKB7MS6SPWW4DKQJX7W',
#  'cars:01K3KY4XKBMSCD9E477ZQ17YVZ',
#  'cars:01K3KY4XKBJPG3D0807NNP8WC3',
#  'cars:01K3KY4XKBWWXFH18Y473W7G6B',
#  'cars:01K3KY4XKBS5D809VQY7PQ8QRC',
#  'cars:01K3KY4XKBJ8ZDE8AK3AKWDZ6Z',
#  'cars:01K3KY4XKBNN6P0668D815NEC1',
#  'cars:01K3KY4XKBE0TBJ01VTT1TFHZS',
#  'cars:01K3KY4XKCPCVH83FK2EA71Z48',
#  'cars:01K3KY4XKC73XMV3GBFCT7J0WW',
#  'cars:01K3KY4XKC5KV2AKX0CGXVH5RZ',
#  'cars:01K3KY4XKCX1H1N5GXK2PY1HHD',
#  'cars:01K3KY4XKC2D62TXN60TFZZVY5',
#  'cars:01K3KY4XKCH1BDH5Z90PSNF5S4',
#  'cars:01K3KY4XKCHWZK9FW9CVKS1ASM',
#  'cars:01K3KY4XKCJ94D3SBZF1F1YYH3',
#  'cars:01K3KY4XKCBAFQ964BAV94YAN0',
#  'cars:01K3KY4XKC2NY2N5XYAW7K6YZ6',
#  'cars:01K3KY4XKCAPFHNRHMJ7BW0CME',
#  'cars:01K3KY4XKCDB5YYVT0776P48R0',
#  'cars:01K3KY4XKC1TSCSCKJ67WZ04SV',
#  'cars:01K3KY4XKCE0GXB8CHSJP1A00Q',
#  'cars:01K3KY4XKCN4B08WG2PYSM70BJ',
#  'cars:01K3KY4XKC50XEKZPM2FMRXCKG',
#  'cars:01K3KY4XKCZRN029JGZ9JE0JQQ',
#  'cars:01K3KY4XKCWR2KYMJVYV0VVGWK',
#  'cars:01K3KY4XKCCWRMW2TDY5B2FZ7Q',
#  'cars:01K3KY4XKCKSDQZHJ02W2H2B6G',
#  'cars:01K3KY4XKCFN5YDRA3HNNNXFDB',
#  'cars:01K3KY4XKCXJ5XNSFY197P9M27',
#  'cars:01K3KY4XKC6SF9HZSBRX70VSH8',
#  'cars:01K3KY4XKCWTZ9ERQHFD9WG9PM',
#  'cars:01K3KY4XKCY3ZD176718N45V71',
#  'cars:01K3KY4XKC4XZN931SSWJP74P0',
#  'cars:01K3KY4XKC9Z1GPP9ABWW297M1',
#  'cars:01K3KY4XKCE6Z0EPJKWG7N7GGQ',
#  'cars:01K3KY4XKCYJ57RSQDJM7K6EFG',
#  'cars:01K3KY4XKCBMKCPCT2KRDVGEG5',
#  'cars:01K3KY4XKCXC7D9M2G1BXX2R8F',
#  'cars:01K3KY4XKCG6KERMEM80A3RAAZ',
#  'cars:01K3KY4XKCNCX9F4G1Y7H44S3S',
#  'cars:01K3KY4XKCF153RPXWFRBK0QG5',
#  'cars:01K3KY4XKCHXNB6WMF9HRRZ412',
#  'cars:01K3KY4XKCMXEDN1JQHTXKKTDN',
#  'cars:01K3KY4XKCSX846C67FYSXN6ZR',
#  'cars:01K3KY4XKCGJY54D9T45BQPY55',
#  'cars:01K3KY4XKCMEG7R2QQM5MYE3PP',
#  'cars:01K3KY4XKC6NBQRQ4ETHKD090S',
#  'cars:01K3KY4XKCDTB4AVHNFY9CX34N',
#  'cars:01K3KY4XKC2JFZAJ878A3S9GZ9',
#  'cars:01K3KY4XKCVCQVM1V9NJV4B6RC',
#  'cars:01K3KY4XKC7330H6JC31MBPZJH',
#  'cars:01K3KY4XKC9ZXV3ADZR3TDHG1Z',
#  'cars:01K3KY4XKC884QN3FVXT2AW067',
#  'cars:01K3KY4XKC7Q4TJ5CYV4GNXWNP',
#  'cars:01K3KY4XKC20J1XK5NBZ0F9QCJ',
#  'cars:01K3KY4XKCD2E0XSQ1B1257ZMX',
#  'cars:01K3KY4XKCEYZ9RENGCEQAGZ6C',
#  'cars:01K3KY4XKC97SWS7D34VXR3BTA',
#  'cars:01K3KY4XKC8SD33PCV73D5GJHV',
#  'cars:01K3KY4XKCRCH40DGW9K8DM6BR',
#  'cars:01K3KY4XKCM6SGFZB2J3ZRSVXJ',
#  'cars:01K3KY4XKCHXM25926JZRXFFRT',
#  'cars:01K3KY4XKCRZPSW28J8SNAF29E',
#  'cars:01K3KY4XKCV73EW2WE2MV6P28J',
#  'cars:01K3KY4XKC5N07JHPDVVYCG8WA',
#  'cars:01K3KY4XKCXS49NSXQV5APQM8C',
#  'cars:01K3KY4XKCZW34RRWNKBV6CWHX',
#  'cars:01K3KY4XKCE38EJGPQ664HR0S8',
#  'cars:01K3KY4XKCG6STKQ9Q1CA7A793',
#  'cars:01K3KY4XKCF04XXK204CK571FE',
#  'cars:01K3KY4XKCMXMMHV39N4T24ZKE',
#  'cars:01K3KY4XKCNZM085V5FMQASBBT',
#  'cars:01K3KY4XKCZ6RJYR61QEQ5HN1B',
#  'cars:01K3KY4XKCXW0GEXZAFJB0VGRX',
#  'cars:01K3KY4XKCB4CVKRHX8XMWGFP1',
#  'cars:01K3KY4XKC6KQA5ZDPPZ41KYQD',
#  'cars:01K3KY4XKCEQ86M8NWYMK3QK12',
#  'cars:01K3KY4XKCRD8MSEJFPB4DQ79B',
#  'cars:01K3KY4XKCD13MDN1D72DZ62MX',
#  'cars:01K3KY4XKC4XQ7CRD6G1XNHYEH',
#  'cars:01K3KY4XKCRFCPFE2K240S1FDJ',
#  'cars:01K3KY4XKC4PGY540BSVNXMNC5',
#  'cars:01K3KY4XKCEA5MDNVWD0WVPYVN',
#  'cars:01K3KY4XKCM1MCRJG6G5QWHDPB',
#  'cars:01K3KY4XKCNKGZ9237T41MNGZ3',
#  'cars:01K3KY4XKCVP7FDDS77KFV0TFG',
#  'cars:01K3KY4XKCNYNE6RAYRQ06BQVT',
#  'cars:01K3KY4XKC172KHV4BGB284FMZ',
#  'cars:01K3KY4XKCYJNDKFKW5X6NFJZW',
#  'cars:01K3KY4XKC3PFKDSNJSWCJ2CV8',
#  'cars:01K3KY4XKCQD4B7CGSFYYDH99G',
#  'cars:01K3KY4XKCYB7V4F4K54N9EB3E',
#  'cars:01K3KY4XKCQH16DCMY0J4M2SW5',
#  'cars:01K3KY4XKC8SW4K7TTAW2BSSQP',
#  'cars:01K3KY4XKC1MWF5C7J277HXP9Q',
#  'cars:01K3KY4XKCQ58467MAJRT7CGHJ',
#  'cars:01K3KY4XKC6QN3TNWWN5SDZQRH',
#  'cars:01K3KY4XKC8CT7ZYDBJWFTKKKP',
#  'cars:01K3KY4XKCJGY153DBG59F4EW2',
#  'cars:01K3KY4XKCTP4MS8EC299XAQE3',
#  'cars:01K3KY4XKCMPDSRGRKNY8X4AV3',
#  'cars:01K3KY4XKC2R4M324MQNZCFQCA',
#  'cars:01K3KY4XKCBMDVXTM40NHRF596',
#  'cars:01K3KY4XKCK16Z8WR8QSC8CSG3',
#  'cars:01K3KY4XKCDB955M4PS11EN6R3',
#  'cars:01K3KY4XKCRR27A0FM30DPSESX',
#  'cars:01K3KY4XKCGH7V8Z5MMSV3TF61',
#  'cars:01K3KY4XKCQ1CD5CEQRXR3PYPX',
#  'cars:01K3KY4XKCKAMBSTXPMAJA6GR4',
#  'cars:01K3KY4XKCWAA1FY1V8A81X420',
#  'cars:01K3KY4XKCVFCCHBF5SQ416CW7',
#  'cars:01K3KY4XKCTKBAGZYM48JYZTY4',
#  'cars:01K3KY4XKC4E8RM1AGW73K0FBV',
#  'cars:01K3KY4XKCT4ANPK0ZWVM0VZF3',
#  'cars:01K3KY4XKCW76ZH894B4HBBZGY',
#  'cars:01K3KY4XKCBPNZR56CT7TE7C9C',
#  'cars:01K3KY4XKCAQ6KMSG8FWJ0AKRY',
#  'cars:01K3KY4XKCTJKQFGD1209R054M',
#  'cars:01K3KY4XKC6M4880W411F2A8BS',
#  'cars:01K3KY4XKC1G6BSHFM95VK8ANJ',
#  'cars:01K3KY4XKCNX68N90BTTM47KBM',
#  'cars:01K3KY4XKC1J94G7B2JRAV6N8F',
#  'cars:01K3KY4XKCRHFHJ35CPKQ1349W',
#  'cars:01K3KY4XKCKP425BNQPQ37BX0D',
#  'cars:01K3KY4XKCFWQ93YX3MPWX1T8Y',
#  'cars:01K3KY4XKCQ87H8E759BA01DQ6',
#  'cars:01K3KY4XKCNSYEW2ZF7ASH6X8Z',
#  'cars:01K3KY4XKC2PF4D6NYJEVSEN73',
#  'cars:01K3KY4XKCWYBG935J96Z1Y5GR',
#  'cars:01K3KY4XKCJJP2MGCMK23RYMS0',
#  'cars:01K3KY4XKC44WF6AY0JPJGCDYQ',
#  'cars:01K3KY4XKC19CPKGC56T4Z2N8T',
#  'cars:01K3KY4XKCF6Z8VTJH848KQXN8',
#  'cars:01K3KY4XKC9DCG85FZQ32R2J5M',
#  'cars:01K3KY4XKCM96NG95K9CKM8H9W',
#  'cars:01K3KY4XKCNW70SZVACJ4F0BBJ',
#  'cars:01K3KY4XKCWZ7X6CQM0QVK0677',
#  'cars:01K3KY4XKC1TS1GM8YCPEC05D1',
#  'cars:01K3KY4XKCSRRVDCH7VZ08YMZV',
#  'cars:01K3KY4XKCRSB68MQY0S85K1N0',
#  'cars:01K3KY4XKCDFDYM74T72J6B22X',
#  'cars:01K3KY4XKCSD5SDNJNKVXZ1MM8',
#  'cars:01K3KY4XKC9EW20CBS0B54CFCT',
#  'cars:01K3KY4XKCZ4JX4M8X2B6JX709',
#  'cars:01K3KY4XKCNBR86KZJR16TJVJF',
#  'cars:01K3KY4XKCRZER39BJDXM27FMF',
#  'cars:01K3KY4XKC3SD9E22X0YV2PZQ6',
#  'cars:01K3KY4XKCPMY5Z6Q43J18Q27D',
#  'cars:01K3KY4XKCJ4S7BJ3QW9KAAMTB',
#  'cars:01K3KY4XKCEM0CABENAKZDFSZT',
#  'cars:01K3KY4XKCP4S4QABNR620NB39',
#  'cars:01K3KY4XKCH400MVKT09EDJNF6',
#  'cars:01K3KY4XKCK82A3DK8ZBPSAZFE',
#  'cars:01K3KY4XKCRYGF4MHT5FZCS3YN',
#  'cars:01K3KY4XKCA2N41T4MDNSKXSB9',
#  'cars:01K3KY4XKC298V6G8W0XX3C2VW',
#  'cars:01K3KY4XKCB27X1RM491PKXMVV',
#  'cars:01K3KY4XKCX33B5MFTEFGBRG41',
#  'cars:01K3KY4XKCF1D59C951RFRHFAD',
#  'cars:01K3KY4XKC8D9F8AMAWG2TZ2ZP',
#  'cars:01K3KY4XKC3WTQVTAMVD8YMHJB',
#  'cars:01K3KY4XKCV19X7CRYT7305JTW',
#  'cars:01K3KY4XKC1PZ5NQWF5CBAM8PX',
#  'cars:01K3KY4XKCK5PZNYTG0NGE4JMH',
#  'cars:01K3KY4XKCFE0PVC7QVEVMJ7QS',
#  'cars:01K3KY4XKC1WR798DNJQ0MY34G',
#  'cars:01K3KY4XKCMVTSFJF83M6DW19Q',
#  'cars:01K3KY4XKCBX7NG7YBMYQC5CWZ',
#  'cars:01K3KY4XKCD2KHA69GVJ4WS6Y9',
#  'cars:01K3KY4XKCFJRH9Q65A3FPP7XC',
#  'cars:01K3KY4XKCXVG31SNKFDKJM4MH',
#  'cars:01K3KY4XKCA7NBF9429HY9YC2K',
#  'cars:01K3KY4XKCEG4NET6NQE9MWA5M',
#  'cars:01K3KY4XKCBPV5FDYS26M7Z3XJ',
#  'cars:01K3KY4XKCYX1S1DGNBHQAJ0ZV',
#  'cars:01K3KY4XKCW4V75SZNKFPQT7Y1',
#  'cars:01K3KY4XKCTEGDGNA0WH5PWJDT',
#  'cars:01K3KY4XKCETTPNFS2R2KJ9BGV',
#  'cars:01K3KY4XKCKBREY2SMC9W8NGM3',
#  'cars:01K3KY4XKCSYP79NCDY2T636PA',
#  'cars:01K3KY4XKCQ0TQ5MCG0MGHW352',
#  'cars:01K3KY4XKC3KWKPXFAT91BTHAR',
#  'cars:01K3KY4XKCH12X1MGMYNYYBJ5A',
#  'cars:01K3KY4XKCGQ7SYKPZRPC3NFE4',
#  'cars:01K3KY4XKCE9Q9FC2RP98AQ4DY',
#  'cars:01K3KY4XKC6PC65FQSZ0HR468J',
#  'cars:01K3KY4XKCEXE7V5M9F8D851MC',
#  'cars:01K3KY4XKCYY3YRC9M1VQPVAK1',
#  'cars:01K3KY4XKC2ZYRVQ4HW1VT31T3',
#  'cars:01K3KY4XKCMNV6JQJXD1RKSYSZ',
#  'cars:01K3KY4XKC4WQ0YEXQ3VQHFG21',
#  'cars:01K3KY4XKCNWYZT0Z3QHXAWST7',
#  'cars:01K3KY4XKCABRR08VZXCS8BW8C',
#  'cars:01K3KY4XKC0KG7QAR5Q2FDRVAB',
#  'cars:01K3KY4XKCRCJFN0F5ZJAZG6ZQ',
#  'cars:01K3KY4XKCBQP96D1P76HRXT3P',
#  'cars:01K3KY4XKCBHKNGE42TDACG28T',
#  'cars:01K3KY4XKCWFHY9J0CT2RVHCC6',
#  'cars:01K3KY4XKCK69SF474Z1C9511E',
#  'cars:01K3KY4XKCT3WVJD0VFENHZF80',
#  'cars:01K3KY4XKCAJY0BF0BDBQ6SKFF',
#  'cars:01K3KY4XKC6HYPEG68D459H9QK',
#  'cars:01K3KY4XKCAB5NKQKH7PKVGQBB',
#  'cars:01K3KY4XKCJG0M4RJDV6Y9G6S0',
#  'cars:01K3KY4XKCMJ0WKBYC1M1TTH1B',
#  'cars:01K3KY4XKCB05JZZN0C2DHJXBK',
#  'cars:01K3KY4XKCJK2TSB2A5104TWJF',
#  'cars:01K3KY4XKCNMMA21VGTWF9WKFC',
#  'cars:01K3KY4XKC5MTBCZ321MV5GPBW',
#  'cars:01K3KY4XKC5XM1XTEBQJGSBYHQ',
#  'cars:01K3KY4XKCWQXABHGH18KGD2ZG',
#  'cars:01K3KY4XKCCC3FZ7YKTB25HQC7',
#  'cars:01K3KY4XKC0V1J3WJ19YYVN2HQ',
#  'cars:01K3KY4XKCF1DKKDKQ2G902GQA',
#  'cars:01K3KY4XKC8ZYSYGWK83W13FNF',
#  'cars:01K3KY4XKC8H8CY57Q4XT2RQYF',
#  'cars:01K3KY4XKC935ZZKMAAEC84QVC',
#  'cars:01K3KY4XKCT6EFAQXGVH3NJ8G0',
#  'cars:01K3KY4XKC10G7YVTA57A0J34S',
#  'cars:01K3KY4XKCTV935RCG4QGXYFE2',
#  'cars:01K3KY4XKCB6WXE0720TJ5MTX4',
#  'cars:01K3KY4XKCCC1FW86A1TMDFNPP',
#  'cars:01K3KY4XKCA2WF7SNPNS1H8CTR',
#  'cars:01K3KY4XKCPDMTQFW46ZX84N0A',
#  'cars:01K3KY4XKCYXJKKS86VZE7N2RZ',
#  'cars:01K3KY4XKC0VBRSEJMKNVSASEN',
#  'cars:01K3KY4XKCZ1XPKSYF8H4F0QV4',
#  'cars:01K3KY4XKCR9ZDAQWHYTGGX1H3',
#  'cars:01K3KY4XKCVZS0KXNW1QZ7ENC7',
#  'cars:01K3KY4XKCDRF7X3QX2PH7NVBW',
#  'cars:01K3KY4XKC8VMSBP284WFGRBDC',
#  'cars:01K3KY4XKC0CRKEMEZASHTXBKQ',
#  'cars:01K3KY4XKC1P3AC0J7GCMJMBVY',
#  'cars:01K3KY4XKCW6TGFDWN12RNC2F4',
#  'cars:01K3KY4XKCHWHS9A7YD95QWNY6',
#  'cars:01K3KY4XKC1HF10HGN4FYC2KDZ',
#  'cars:01K3KY4XKCNWB95NHWRQGGDHHR',
#  'cars:01K3KY4XKCJG6WR7QKHK814K3Y',
#  'cars:01K3KY4XKCQH9JTPEY7Q5KEMPX',
#  'cars:01K3KY4XKCM48TPJSAPFH67YE0',
#  'cars:01K3KY4XKDE8YNCKAWTVHQ0M6G',
#  'cars:01K3KY4XKDK912DF3HC4ENQ6G6',
#  'cars:01K3KY4XKD5A16Y0GQF81D4M5K',
#  'cars:01K3KY4XKDC689CN5WSKV146B4',
#  'cars:01K3KY4XKDC529GCDR22499DYF',
#  'cars:01K3KY4XKDYRR8V2EVRMMB7ZKJ',
#  'cars:01K3KY4XKD6EHWD7EMNJETM1QT',
#  'cars:01K3KY4XKDF8ZB3KGAQ2JKWK8N',
#  'cars:01K3KY4XKD7M2PE10V9VA4KCD5',
#  'cars:01K3KY4XKDRMPYCRZNVMNA937N',
#  'cars:01K3KY4XKDRXTX3PRP9EFW7GSZ',
#  'cars:01K3KY4XKDSQ3P6TS7GEF3Z2FT',
#  'cars:01K3KY4XKDFXY3X2BC32VFER85',
#  'cars:01K3KY4XKDH39YKHZGDWT41N2Q',
#  'cars:01K3KY4XKD9EDP55GPQHCT5KP6',
#  'cars:01K3KY4XKD4YBD24SAFGWTSYR2',
#  'cars:01K3KY4XKD8F2RBYGCE9AYFPNJ',
#  'cars:01K3KY4XKDWG5HDDF1DJ215GAE',
#  'cars:01K3KY4XKDZ9YVM2RS1VBFHABG',
#  'cars:01K3KY4XKDFRWDP7QS3B738A4Z',
#  'cars:01K3KY4XKDW2FSNPWAR0SDGK3B',
#  'cars:01K3KY4XKDKXZHDBSDVY0YQ936',
#  'cars:01K3KY4XKDPT8SGKCDT662S5FY',
#  'cars:01K3KY4XKDR8YF76RE280EFG7V',
#  'cars:01K3KY4XKDB6BNZ6VP4963Y4S0',
#  'cars:01K3KY4XKD12N299F4NNTN22P2',
#  'cars:01K3KY4XKDBKFZBHFRES8N0P6E',
#  'cars:01K3KY4XKDYQBC28S08HG847NM',
#  'cars:01K3KY4XKD4B36PHQ7JWXM44XE',
#  'cars:01K3KY4XKD6HNSV9JKJ4WDBXX1',
#  'cars:01K3KY4XKD84AN6DC314NHDEZ2',
#  'cars:01K3KY4XKD7KSFXSQ53ZEK9Z6G',
#  'cars:01K3KY4XKDQ7VC2P299DK3NB2Q',
#  'cars:01K3KY4XKD57ZGSD9RANAJ2DKQ',
#  'cars:01K3KY4XKD9S5GAGB36JFPKV3V',
#  'cars:01K3KY4XKD69TZJ7FKKGWMEMB7',
#  'cars:01K3KY4XKD97MCTSWSH1161MVN',
#  'cars:01K3KY4XKDRQ2SC82AWQ8MNCWN',
#  'cars:01K3KY4XKDJRJM8NENDTDX93YX',
#  'cars:01K3KY4XKD4VHBPN9Q85TFQHTB',
#  'cars:01K3KY4XKD7J6585F4PQ967CN8',
#  'cars:01K3KY4XKDYG7E75AZGDN60632',
#  'cars:01K3KY4XKDAZPQXQ0YC8JR2CAV',
#  'cars:01K3KY4XKD4YH6Y8R0KN9K31CA',
#  'cars:01K3KY4XKD5FFDEQXKCQ3T5F9K',
#  'cars:01K3KY4XKDV1JYTC7S725S92PE',
#  'cars:01K3KY4XKDD47XTEBXMBAQDX8T',
#  'cars:01K3KY4XKDBQJ7YCDQMB3VGTQR',
#  'cars:01K3KY4XKDZWGQFDFNK7YQ30N8',
#  'cars:01K3KY4XKDZAW9FE973WW1XHP9',
#  'cars:01K3KY4XKDGFKDMCBD5H7AFQ5Z',
#  'cars:01K3KY4XKDDW5WXXS48XXKHTKG',
#  'cars:01K3KY4XKDWBRPVG204010W2FP',
#  'cars:01K3KY4XKDFQP36J45YHM8Q6QX',
#  'cars:01K3KY4XKD9XA88MZQK25PB1YC',
#  'cars:01K3KY4XKDJWR9NK38FNE5YCH5',
#  'cars:01K3KY4XKD1WGN3FE0NPKS0YAX',
#  'cars:01K3KY4XKDQWDX2FJMHJNVBKYM',
#  'cars:01K3KY4XKDTJ5DP85A6VPSRE92',
#  'cars:01K3KY4XKDDDF48MJRBC68XZ0F',
#  'cars:01K3KY4XKDEB0KEB9YNWW8HXRX',
#  'cars:01K3KY4XKD3X0P80W09J7V05F1',
#  'cars:01K3KY4XKD4E5KSSX71S94NJXB',
#  'cars:01K3KY4XKD5CB6XSJM9VD82A3R',
#  'cars:01K3KY4XKD3QN7XEY3JF49TXGK',
#  'cars:01K3KY4XKD9Z1S8Y761VFH8WP3',
#  'cars:01K3KY4XKDMQHT6GTRVKS8KJX3',
#  'cars:01K3KY4XKDM00MSBWRZ06KDZ2Y',
#  'cars:01K3KY4XKD7CH4JXM0FMW9BP6T',
#  'cars:01K3KY4XKD1YCGKPBTPA40F2NE',
#  'cars:01K3KY4XKDSMS8D1AP49RDD7DG',
#  'cars:01K3KY4XKD8RS0YWZDG97R7SBT',
#  'cars:01K3KY4XKDT5BBZCQ826KQWPED',
#  'cars:01K3KY4XKDFQMJ1QK7XYNFQVNS',
#  'cars:01K3KY4XKDQYSJ4Q2A2GKGP1F0',
#  'cars:01K3KY4XKDB23S7YJJ5735DZ68',
#  'cars:01K3KY4XKDG2B4G5J0YHF1RFFG',
#  'cars:01K3KY4XKD3TYCHSDA21Z9Y39B',
#  'cars:01K3KY4XKD7MWG2STZ61BCW038',
#  'cars:01K3KY4XKDM53DKNQHE0YT7WAP',
#  'cars:01K3KY4XKDW10C3TSB52XRJP0Q',
#  'cars:01K3KY4XKD9Y5EDR1Y2YYY8MNZ',
#  'cars:01K3KY4XKD6RNFDQ5XVEW5JK83',
#  'cars:01K3KY4XKD3VZWQQW2ZAGDDJQA',
#  'cars:01K3KY4XKDNKD3AMKX6SY7PHEW',
#  'cars:01K3KY4XKDTAJ08RS37JYQAFPH',
#  'cars:01K3KY4XKDTWC9R96K2FWBDHJA',
#  'cars:01K3KY4XKDAC8W91XC88WTXG85',
#  'cars:01K3KY4XKD6G9NK3E6WZRDWAN0',
#  'cars:01K3KY4XKDJ36ND2QAP5HD2G1Q',
#  'cars:01K3KY4XKDJWPCA18WX8BKVN0Z',
#  'cars:01K3KY4XKDNFY1QHYTB50NF9X0',
#  'cars:01K3KY4XKD2P0WJNR0J2ECE4F3',
#  'cars:01K3KY4XKD7DHXNN721X2Z4901',
#  'cars:01K3KY4XKDX7WJMXCQHN01ZWEW',
#  'cars:01K3KY4XKD3N61BPZYM9RHKB76',
#  'cars:01K3KY4XKDT39H578M5SCDRS4W',
#  'cars:01K3KY4XKD36GVZZPHR5HW6BTE',
#  'cars:01K3KY4XKDH46WXPQ411RE05AA',
#  'cars:01K3KY4XKD77E8MREKF5BTTQWC',
#  'cars:01K3KY4XKDZ6PAEKNKGHA49MDY',
#  'cars:01K3KY4XKDZ4VCWP13S9JYQ1KE',
#  'cars:01K3KY4XKDM4X9T68MVY8XEC77',
#  'cars:01K3KY4XKDNE3P2VC8XSPTK2FB',
#  'cars:01K3KY4XKDZPKNV2A7FHZ8Q15Y',
#  'cars:01K3KY4XKD3JGBMPGY8QWJCSBF',
#  'cars:01K3KY4XKD5JC2E4FWPTEXYXP9',
#  'cars:01K3KY4XKDCP8TKVWM2CPGR46Y',
#  'cars:01K3KY4XKDCGWA1SBNMP9ZQ8CY',
#  'cars:01K3KY4XKD4GGBS7RFN3RTDG7W',
#  'cars:01K3KY4XKD8EV0T32GA88XFD5M',
#  'cars:01K3KY4XKDSGCNKV26B7G00SM1',
#  'cars:01K3KY4XKDNQ04PETXE4EB1NCW',
#  'cars:01K3KY4XKDY4B7492NE2F19RHN',
#  'cars:01K3KY4XKD37BN33XTMZBQAYZD',
#  'cars:01K3KY4XKD4X39XY2YJ6WFGVMT',
#  'cars:01K3KY4XKDVV33A45E0KWMANJ7',
#  'cars:01K3KY4XKDYHDVPWPWV7T8SD51',
#  'cars:01K3KY4XKDKJB31DCPNB8219DV',
#  'cars:01K3KY4XKDWPAVH6V4WCZQHS7V',
#  'cars:01K3KY4XKDSZ4VQX8SCJH5MW7J',
#  'cars:01K3KY4XKDE4JS9Z6B8F48CR79',
#  'cars:01K3KY4XKDRR161G9WEBXZ7N6Q',
#  'cars:01K3KY4XKDT19Z8HWXNPFY7N6A',
#  'cars:01K3KY4XKD24CJ2Z6X5MXXS7AV',
#  'cars:01K3KY4XKDGK035B9J5ZCE849C',
#  'cars:01K3KY4XKD7TW2TKNVHHG3FC8Q',
#  'cars:01K3KY4XKDWD641Z3X3D1EGZ4Z',
#  'cars:01K3KY4XKDB3PKF9M9KJW70GC4',
#  'cars:01K3KY4XKD54GN408MR4WX8DPA',
#  'cars:01K3KY4XKDEM3J8QT58F5CWQZB',
#  'cars:01K3KY4XKD8Q9NMC2TTVCK55QS',
#  'cars:01K3KY4XKDXKB7WYHPBY96VDDN',
#  'cars:01K3KY4XKDGG9D6B6QFAVEQ1C7',
#  'cars:01K3KY4XKDC71F92HZE9X58NVR',
#  'cars:01K3KY4XKDH8X7ZW7YWV2999BM',
#  'cars:01K3KY4XKDV0H38VXE9FPTCM1W',
#  'cars:01K3KY4XKDV8FS1Q4NBWQGRC0M',
#  'cars:01K3KY4XKDFD4T99R4PV9EY39G',
#  'cars:01K3KY4XKDPGP7596P0GXBHTY9',
#  'cars:01K3KY4XKDB7D2EH5R96PQA55J',
#  'cars:01K3KY4XKD3DCAM7SQWPZHZ64P',
#  'cars:01K3KY4XKDD7H9YJBBP1XRFAPR',
#  'cars:01K3KY4XKDER9B9BSV73R38F8S',
#  'cars:01K3KY4XKDWBXSVWGC9444B4VE',
#  'cars:01K3KY4XKDBQ1Q0Q55HXVZZ0HY',
#  'cars:01K3KY4XKDE73WGNGHACSC2PB1',
#  'cars:01K3KY4XKDPT3C3G9DFQFPS62Y',
#  'cars:01K3KY4XKDASPNHXQ7ST7ZTGYW',
#  'cars:01K3KY4XKDQ3NEJH6QH8BQ8HDB',
#  'cars:01K3KY4XKDGA3XH8ECSGH3CDDM',
#  'cars:01K3KY4XKDQHPBN13JCRGDK6PG',
#  'cars:01K3KY4XKD4PGSYVY4KM6A8QNT',
#  'cars:01K3KY4XKDK5AZPXPF97AVAMXB',
#  'cars:01K3KY4XKDFHYDDEDAWSF9KEDG',
#  'cars:01K3KY4XKDK179MH8N2GQBHFS5',
#  'cars:01K3KY4XKDC7SZZRYPY90X8BFW',
#  'cars:01K3KY4XKDCP8D1KY85QYS8XDB',
#  'cars:01K3KY4XKDJ79YE2WX8NKG6F6D',
#  'cars:01K3KY4XKDTB6TD1F9EN8RPEJB',
#  'cars:01K3KY4XKDR6NMT8QS9FY9A763',
#  'cars:01K3KY4XKDAGGQF224PKWC9XFA',
#  'cars:01K3KY4XKDKRNE8JGCW95NYQSV',
#  'cars:01K3KY4XKD7GTZB416X46EH4X4',
#  'cars:01K3KY4XKDGYXTRP2N18DWH2R9',
#  'cars:01K3KY4XKD9R3D2RNFNNAQYRSC',
#  'cars:01K3KY4XKDS3VV5R6ZYP3484HN',
#  'cars:01K3KY4XKD7HRQY1AQK7SX8P4P',
#  'cars:01K3KY4XKDZE3YKQ3CV5KT6190',
#  'cars:01K3KY4XKD7ZB8H21AT1DNQD9J',
#  'cars:01K3KY4XKD96RQY82KB0ZS4WV8',
#  'cars:01K3KY4XKD264VZAYDHC12D5VF',
#  'cars:01K3KY4XKDWK2QSCYWPTEZ5CQ1',
#  'cars:01K3KY4XKDWB0D3JAWG7Q722ZK',
#  'cars:01K3KY4XKDEGZ5W1XY8DD9Z10R',
#  'cars:01K3KY4XKDZZC893XST16VYSFS',
#  'cars:01K3KY4XKDTB9ARMC4WGSM1VYA',
#  'cars:01K3KY4XKDSJ9RFNFMKTSXZCMH',
#  'cars:01K3KY4XKDB9QKVFRJF4D3QH4C',
#  'cars:01K3KY4XKDJSEZ271HMD9RNC83',
#  'cars:01K3KY4XKDQ2M91N0WHATCHC2P',
#  'cars:01K3KY4XKDRRMT4DN86SNTW1MP',
#  'cars:01K3KY4XKDEFK8MR6ZAEYXQNHY',
#  'cars:01K3KY4XKD7ZFVGF8EJZJCZ7H9',
#  'cars:01K3KY4XKD5DRTP7M0TYAHC89A',
#  'cars:01K3KY4XKDJMN8E6VRB1RJWAZ6',
#  'cars:01K3KY4XKDS01E74C0G339KHVA',
#  'cars:01K3KY4XKDFECPKH7WTF61WST0',
#  'cars:01K3KY4XKD6QZS69S9CDG6TZ71',
#  'cars:01K3KY4XKDR5BAZJJF9450G164',
#  'cars:01K3KY4XKD75R40XPN0HT4EQ8Y',
#  'cars:01K3KY4XKDVFMGW0HDHGB8XXEE',
#  'cars:01K3KY4XKDB6X456JHX74SEWH0',
#  'cars:01K3KY4XKDPSD0YNVA196X7XM8',
#  'cars:01K3KY4XKDZQW3WFYRT15YXM02']

# %% [markdown]
# # Check index created successfully

# %%
index.info()["num_docs"]
# Out:
# 464

# %% [markdown]
# # Review search study config
#
# - index_name should point to index created above
# - qrels and queries should point to the queries and set of labeled queries under test
# - search methods should match with the custom methods defined below
# - embedding_model should match with the one used to create the index

# %%
from redis_retrieval_optimizer.utils import load_search_study_config

search_study_config = load_search_study_config("search_study_config.yaml")
search_study_config
# Out:
# SearchStudyConfig(study_id='test-search-study', index_name='cars', qrels='../resources/cars/car_qrels.json', queries='../resources/cars/car_queries.json', search_methods=['base_vector', 'pre_filter_vector'], ret_k=3, id_field_name='_id', vector_field_name='vector', text_field_name='text', embedding_model=EmbeddingModel(type='hf', model='sentence-transformers/all-mpnet-base-v2', dim=768, embedding_cache_name='vec-cache', dtype='float32'))

# %% [markdown]
# # Define search methods for search study
#
# A search method can be anything as long as it takes a `SearchMethodInput` and returns a `SearchMethodOutput`. Below we will compare a basic vector search to a vector search with a pre-filter.

# %%
from ranx import Run
from redis_retrieval_optimizer.search_methods.base import run_search_w_time
from redisvl.query import VectorQuery
from redisvl.query.filter import Tag

from redis_retrieval_optimizer.schema import SearchMethodInput, SearchMethodOutput
from redis_retrieval_optimizer.search_methods.vector import make_score_dict_vec

def vector_query(query_info, num_results: int, emb_model) -> VectorQuery:
    vector = emb_model.embed(query_info["query"], as_buffer=True)

    return VectorQuery(
        vector=vector,
        vector_field_name="vector",
        num_results=num_results,
        return_fields=["item_id", "make", "model", "text"]
    )

def pre_filter_query(query_info, num_results, emb_model) -> VectorQuery:
    vec = emb_model.embed(query_info["query"])
    make = query_info["query_metadata"]["make"]
    model = query_info["query_metadata"]["model"]

    filter = (Tag("make") == make) & (Tag("model") == model)

    # Create a vector query
    query = VectorQuery(
        vector=vec,
        vector_field_name="vector",
        num_results=num_results,
        filter_expression=filter,
        return_fields=["item_id", "make", "model", "text"]
    )

    return query

def gather_pre_filter_results(search_method_input: SearchMethodInput) -> SearchMethodOutput:
    redis_res_vector = {}

    for key, query_info in search_method_input.raw_queries.items():
        # create the query
        query = pre_filter_query(query_info, search_method_input.ret_k, search_method_input.emb_model)

        # run with timing helper function
        res = run_search_w_time(
            search_method_input.index, query, search_method_input.query_metrics
        )

        # format into scores dict
        score_dict = make_score_dict_vec(res, id_field_name="item_id")

        redis_res_vector[key] = score_dict

    # return search method output
    return SearchMethodOutput(
        run=Run(redis_res_vector),
        query_metrics=search_method_input.query_metrics,
    )


def gather_vector_results(search_method_input: SearchMethodInput) -> SearchMethodOutput:
    redis_res_vector = {}

    for key, query_info in search_method_input.raw_queries.items():
        # get query
        vec_query = vector_query(query_info, search_method_input.ret_k, search_method_input.emb_model)

        # run with timing helper function
        res = run_search_w_time(
            search_method_input.index, vec_query, search_method_input.query_metrics
        )

        # format into scores dict
        score_dict = make_score_dict_vec(res, id_field_name="item_id")
        redis_res_vector[key] = score_dict
    
    # return search method output
    return SearchMethodOutput(
        run=Run(redis_res_vector),
        query_metrics=search_method_input.query_metrics,
    )

# %% [markdown]
# # Run the search study

# %%
from redis_retrieval_optimizer.search_study import run_search_study
