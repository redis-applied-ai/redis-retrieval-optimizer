# %% [markdown]
# # Search study
#
# Let's say you have an existing Redis database with a search index seeded. You may wish to quickly test different search method against the existing index without having to recreate data and/or recreate the index. This demo will walk you though how to set this up and get going.
#
# # Installation

# %%
# %pip install redis-retrieval-optimizer

# %% [markdown]
# # Load data
#
# We will load our custom car dataset for this example.

# %%
import json

with open('../resources/cars/car_corpus.json', 'r') as f:
    corpus = json.load(f)

with open('../resources/cars/car_queries.json', 'r') as f:
    queries = json.load(f)

with open('../resources/cars/car_qrels.json', 'r') as f:
    qrels = json.load(f)

# %% [markdown]
# # Create the index with redisvl
#
# For the search_study we are assuming that the search index already exists. The cell below will create a Redis search index and populate it with our test data for example purposes but is assumed with a search study is populated and running within your data.
#
# Note: the demo assumes you have a instance of redis running on localhost:6379. If this is not the case, update the redis_url to direct to your running instance or start a local instance with the following command.
#
# `docker run -d --name redis-stack-server -p 6379:6379 redis/redis-stack-server:latest`

# %%
from redisvl.index import SearchIndex
from redisvl.utils.vectorize import HFTextVectorizer

emb_model = HFTextVectorizer()

# define schema
car_schema = {
    "index": {
        "name": "cars",
        "prefix": "cars"
    },
    "fields": [
        {"name": "item_id", "type": "tag"},
        {"name": "text", "type": "text"},
        {"name": "make", "type": "tag"},
        {"name": "model", "type": "tag"},
        {
            "name": "vector",
            "type": "vector",
            "attrs": {
                "dims": 768,
                "distance_metric": "cosine",
                "algorithm": "FLAT",
                "datatype": "float32"
            },
        },
    ]
}

# assuming you have a redis instance running on localhost:6379
redis_url = "redis://localhost:6379"

# create index
index = SearchIndex.from_dict(car_schema, redis_url=redis_url)
index.create(overwrite=True)

embeddings = emb_model.embed_many([c["text"] for c in corpus], as_buffer=True)

# vectorize corpus data
corpus_data = [
    {
        "text": c["text"],
        "item_id": c["item_id"],
        "make": c["query_metadata"]["make"],
        "model": c["query_metadata"]["model"],
        "vector": embeddings[i]
    }
    for i, c in enumerate(corpus)
]

index.load(corpus_data)
# Out:
# 15:15:56 sentence_transformers.SentenceTransformer INFO   Use pytorch device_name: mps
# 15:15:56 sentence_transformers.SentenceTransformer INFO   Load pretrained SentenceTransformer: sentence-transformers/all-mpnet-base-v2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ['cars:01K1KH06CQXD7SQP42Y3APYJSD',
#  'cars:01K1KH06CQ2WZYCE9HG8NQ6ND1',
#  'cars:01K1KH06CQNBFN1RHJ6K76QJF5',
#  'cars:01K1KH06CQPWG7BD239XEAH6EA',
#  'cars:01K1KH06CQXAW3N3B5XA01HJA0',
#  'cars:01K1KH06CQRDPRAPJ9954HCGCD',
#  'cars:01K1KH06CQZSHNXGXBCYY87K7D',
#  'cars:01K1KH06CQQVJ3PX0BE1NTWK1F',
#  'cars:01K1KH06CQZYQRXHATGJW75XH5',
#  'cars:01K1KH06CQXMCBGJQ6BDM2D047',
#  'cars:01K1KH06CQCB466XYVGNYSKHFQ',
#  'cars:01K1KH06CQYG9MKB67RXSAVZ50',
#  'cars:01K1KH06CQNA1B1EVPF16E54HK',
#  'cars:01K1KH06CQMZV2YP5B7N9SYB1G',
#  'cars:01K1KH06CQCDTDY38KWP0PBXG4',
#  'cars:01K1KH06CVYBF9NEHCPGH4H419',
#  'cars:01K1KH06CV77E8MG59BG93ZZMQ',
#  'cars:01K1KH06CVY59GWGT1RQRF425T']

# %% [markdown]
# # Check index created successfully

# %%
index.info()["num_docs"]
# Out:
# 464

# %% [markdown]
# # Define search methods for search study
#
# A search method can be anything as long as it takes a `SearchMethodInput` and returns a `SearchMethodOutput`. Below we will compare a basic vector search to a vector search with a pre-filter.

# %%
from ranx import Run
from redis_retrieval_optimizer.search_methods.base import run_search_w_time
from redisvl.query import VectorQuery
from redisvl.query.filter import Tag

from redis_retrieval_optimizer.schema import SearchMethodInput, SearchMethodOutput
from redis_retrieval_optimizer.search_methods.vector import make_score_dict_vec

def vector_query(query_info, num_results: int, emb_model) -> VectorQuery:
    vector = emb_model.embed(query_info["query"], as_buffer=True)

    return VectorQuery(
        vector=vector,
        vector_field_name="vector",
        num_results=num_results,
        return_fields=["_id", "make", "model", "text"],  # update to read from env maybe?
    )

def pre_filter_query(query_info, num_results, emb_model) -> VectorQuery:
    vec = emb_model.embed(query_info["query"])
    make = query_info["query_metadata"]["make"]
    model = query_info["query_metadata"]["model"]

    filter = (Tag("make") == make) & (Tag("model") == model)

    # Create a vector query
    query = VectorQuery(
        vector=vec,
        vector_field_name="vector",
        num_results=num_results,
        filter_expression=filter,
        return_fields=["_id", "make", "model", "text"]
    )

    return query

def gather_pre_filter_results(search_method_input: SearchMethodInput) -> SearchMethodOutput:
    redis_res_vector = {}

    for key in search_method_input.raw_queries:
        query_info = search_method_input.raw_queries[key]
        query = pre_filter_query(query_info, 10, search_method_input.emb_model)
        res = run_search_w_time(
            search_method_input.index, query, search_method_input.query_metrics
        )
        score_dict = make_score_dict_vec(res, id_field_name="_id")

        redis_res_vector[key] = score_dict

    return SearchMethodOutput(
        run=Run(redis_res_vector),
        query_metrics=search_method_input.query_metrics,
    )


def gather_vector_results(search_method_input: SearchMethodInput) -> SearchMethodOutput:
    redis_res_vector = {}

    for key in search_method_input.raw_queries:
        text_query = search_method_input.raw_queries[key]
        vec_query = vector_query(text_query, 10, search_method_input.emb_model)
        res = run_search_w_time(
            search_method_input.index, vec_query, search_method_input.query_metrics
        )
        score_dict = make_score_dict_vec(res, id_field_name="_id")
        redis_res_vector[key] = score_dict
        
    return SearchMethodOutput(
        run=Run(redis_res_vector),
        query_metrics=search_method_input.query_metrics,
    )

# %% [markdown]
# # Run the search study

# %%
import os
import sys

# Find the dist directory relative to the project root
project_root = os.path.abspath("../../../")
dist_path = os.path.join(project_root, "dist")

# %%
# %pip install --force-reinstall {dist_path}/*.whl
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Processing /Users/robert.shelton/Documents/redis-retrieval-optimizer/dist/redis_retrieval_optimizer-0.3.0-py3-none-any.whl
# Collecting beir<3.0.0,>=2.1.0 (from redis-retrieval-optimizer==0.3.0)
#   Using cached beir-2.2.0-py3-none-any.whl.metadata (28 kB)
# Collecting nltk<4.0.0,>=3.9.1 (from redis-retrieval-optimizer==0.3.0)
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting numpy<2,>=1 (from redis-retrieval-optimizer==0.3.0)
#   Using cached numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (61 kB)
# Collecting optuna<5.0.0,>=4.3.0 (from redis-retrieval-optimizer==0.3.0)
#   Using cached optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Collecting pandas<3.0.0,>=2.2.3 (from redis-retrieval-optimizer==0.3.0)
#   Downloading pandas-2.3.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting python-dotenv<2.0.0,>=1.1.0 (from redis-retrieval-optimizer==0.3.0)
#   Using cached python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Collecting ranx<0.4.0,>=0.3.20 (from redis-retrieval-optimizer==0.3.0)
#   Using cached ranx-0.3.20-py3-none-any.whl.metadata (17 kB)
# Collecting redis<6.0,>=5.0 (from redis-retrieval-optimizer==0.3.0)
#   Downloading redis-5.3.1-py3-none-any.whl.metadata (9.2 kB)
# Collecting redisvl<1.0.0,>=0.6.0 (from redis-retrieval-optimizer==0.3.0)
#   Using cached redisvl-0.8.0-py3-none-any.whl.metadata (17 kB)
# Collecting sentence-transformers (from beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached sentence_transformers-5.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting pytrec-eval-terrier (from beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached pytrec_eval_terrier-0.5.7-cp312-cp312-macosx_10_13_universal2.whl.metadata (984 bytes)
# Collecting datasets (from beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Downloading datasets-4.0.0-py3-none-any.whl.metadata (19 kB)
# Collecting click (from nltk<4.0.0,>=3.9.1->redis-retrieval-optimizer==0.3.0)
#   Using cached click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting joblib (from nltk<4.0.0,>=3.9.1->redis-retrieval-optimizer==0.3.0)
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting regex>=2021.8.3 (from nltk<4.0.0,>=3.9.1->redis-retrieval-optimizer==0.3.0)
#   Downloading regex-2025.7.34-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting tqdm (from nltk<4.0.0,>=3.9.1->redis-retrieval-optimizer==0.3.0)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting alembic>=1.5.0 (from optuna<5.0.0,>=4.3.0->redis-retrieval-optimizer==0.3.0)
#   Downloading alembic-1.16.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna<5.0.0,>=4.3.0->redis-retrieval-optimizer==0.3.0)
#   Using cached colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting packaging>=20.0 (from optuna<5.0.0,>=4.3.0->redis-retrieval-optimizer==0.3.0)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting sqlalchemy>=1.4.2 (from optuna<5.0.0,>=4.3.0->redis-retrieval-optimizer==0.3.0)
#   Downloading sqlalchemy-2.0.42-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Collecting PyYAML (from optuna<5.0.0,>=4.3.0->redis-retrieval-optimizer==0.3.0)
#   Using cached PyYAML-6.0.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting python-dateutil>=2.8.2 (from pandas<3.0.0,>=2.2.3->redis-retrieval-optimizer==0.3.0)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas<3.0.0,>=2.2.3->redis-retrieval-optimizer==0.3.0)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3.0.0,>=2.2.3->redis-retrieval-optimizer==0.3.0)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting numba>=0.54.1 (from ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached numba-0.61.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.8 kB)
# Collecting tabulate (from ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting scipy>=1.8.0 (from ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Downloading scipy-1.16.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting ir-datasets (from ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached ir_datasets-0.5.11-py3-none-any.whl.metadata (12 kB)
# Collecting rich (from ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Downloading rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting orjson (from ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Downloading orjson-3.11.1-cp312-cp312-macosx_15_0_arm64.whl.metadata (42 kB)
# Collecting lz4 (from ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached lz4-4.4.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting cbor2 (from ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached cbor2-5.6.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.0 kB)
# Collecting seaborn (from ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting fastparquet (from ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached fastparquet-2024.11.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting PyJWT>=2.9.0 (from redis<6.0,>=5.0->redis-retrieval-optimizer==0.3.0)
#   Using cached PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting jsonpath-ng>=1.5.0 (from redisvl<1.0.0,>=0.6.0->redis-retrieval-optimizer==0.3.0)
#   Using cached jsonpath_ng-1.7.0-py3-none-any.whl.metadata (18 kB)
# Collecting ml-dtypes<1.0.0,>=0.4.0 (from redisvl<1.0.0,>=0.6.0->redis-retrieval-optimizer==0.3.0)
#   Downloading ml_dtypes-0.5.3-cp312-cp312-macosx_10_13_universal2.whl.metadata (8.9 kB)
# Collecting pydantic<3,>=2 (from redisvl<1.0.0,>=0.6.0->redis-retrieval-optimizer==0.3.0)
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting python-ulid>=3.0.0 (from redisvl<1.0.0,>=0.6.0->redis-retrieval-optimizer==0.3.0)
#   Using cached python_ulid-3.0.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting tenacity>=8.2.2 (from redisvl<1.0.0,>=0.6.0->redis-retrieval-optimizer==0.3.0)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting Mako (from alembic>=1.5.0->optuna<5.0.0,>=4.3.0->redis-retrieval-optimizer==0.3.0)
#   Using cached mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.12 (from alembic>=1.5.0->optuna<5.0.0,>=4.3.0->redis-retrieval-optimizer==0.3.0)
#   Downloading typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting ply (from jsonpath-ng>=1.5.0->redisvl<1.0.0,>=0.6.0->redis-retrieval-optimizer==0.3.0)
#   Using cached ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba>=0.54.1->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached llvmlite-0.44.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=2->redisvl<1.0.0,>=0.6.0->redis-retrieval-optimizer==0.3.0)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3,>=2->redisvl<1.0.0,>=0.6.0->redis-retrieval-optimizer==0.3.0)
#   Using cached pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3,>=2->redisvl<1.0.0,>=0.6.0->redis-retrieval-optimizer==0.3.0)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.2.3->redis-retrieval-optimizer==0.3.0)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting filelock (from datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting pyarrow>=15.0.0 (from datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Downloading pyarrow-21.0.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting requests>=2.32.2 (from datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting xxhash (from datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached xxhash-3.5.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting huggingface-hub>=0.24.0 (from datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Downloading huggingface_hub-0.34.3-py3-none-any.whl.metadata (14 kB)
# Collecting cramjam>=2.3 (from fastparquet->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Downloading cramjam-2.11.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Collecting beautifulsoup4>=4.4.1 (from ir-datasets->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting inscriptis>=2.2.0 (from ir-datasets->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached inscriptis-2.6.0-py3-none-any.whl.metadata (25 kB)
# Collecting lxml>=4.5.2 (from ir-datasets->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached lxml-6.0.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (6.6 kB)
# Collecting trec-car-tools>=2.5.4 (from ir-datasets->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached trec_car_tools-2.6-py3-none-any.whl.metadata (640 bytes)
# Collecting warc3-wet>=0.2.3 (from ir-datasets->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached warc3_wet-0.2.5-py3-none-any.whl.metadata (2.2 kB)
# Collecting warc3-wet-clueweb09>=0.2.5 (from ir-datasets->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached warc3_wet_clueweb09-0.2.5-py3-none-any.whl
# Collecting zlib-state>=0.1.3 (from ir-datasets->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached zlib_state-0.1.9-cp312-cp312-macosx_12_0_arm64.whl
# Collecting ijson>=3.1.3 (from ir-datasets->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached ijson-3.4.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (21 kB)
# Collecting unlzw3>=0.2.1 (from ir-datasets->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached unlzw3-0.2.3-py3-none-any.whl.metadata (2.3 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Downloading pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Downloading matplotlib-3.10.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Downloading transformers-4.54.1-py3-none-any.whl.metadata (41 kB)
# Collecting torch>=1.11.0 (from sentence-transformers->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached torch-2.7.1-cp312-none-macosx_11_0_arm64.whl.metadata (29 kB)
# Collecting scikit-learn (from sentence-transformers->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Downloading scikit_learn-1.7.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting Pillow (from sentence-transformers->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached pillow-11.3.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.4.1->ir-datasets->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Downloading aiohttp-3.12.15-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub>=0.24.0->datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached hf_xet-1.1.5-cp37-abi3-macosx_11_0_arm64.whl.metadata (879 bytes)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Downloading contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Downloading fonttools-4.59.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (107 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached kiwisolver-1.4.8-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.32.2->datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached charset_normalizer-3.4.2-cp312-cp312-macosx_10_13_universal2.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests>=2.32.2->datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.32.2->datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.32.2->datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Downloading certifi-2025.7.14-py3-none-any.whl.metadata (2.4 kB)
# Collecting setuptools (from torch>=1.11.0->sentence-transformers->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch>=1.11.0->sentence-transformers->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.11.0->sentence-transformers->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch>=1.11.0->sentence-transformers->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers<5.0.0,>=4.41.0->sentence-transformers->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Downloading tokenizers-0.21.4-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.3 (from transformers<5.0.0,>=4.41.0->sentence-transformers->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting cbor>=1.0.0 (from trec-car-tools>=2.5.4->ir-datasets->ranx<0.4.0,>=0.3.20->redis-retrieval-optimizer==0.3.0)
#   Using cached cbor-1.0.0-cp312-cp312-macosx_12_0_arm64.whl
# Collecting MarkupSafe>=0.9.2 (from Mako->alembic>=1.5.0->optuna<5.0.0,>=4.3.0->redis-retrieval-optimizer==0.3.0)
#   Using cached MarkupSafe-3.0.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence-transformers->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached frozenlist-1.7.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached multidict-6.6.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached propcache-0.3.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached yarl-1.20.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (73 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers->beir<3.0.0,>=2.1.0->redis-retrieval-optimizer==0.3.0)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Using cached beir-2.2.0-py3-none-any.whl (77 kB)
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Using cached numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
# Using cached optuna-4.4.0-py3-none-any.whl (395 kB)
# Downloading pandas-2.3.1-cp312-cp312-macosx_11_0_arm64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 33.9 MB/s eta 0:00:001m24.6 MB/s eta 0:00:01
# Using cached python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Using cached ranx-0.3.20-py3-none-any.whl (99 kB)
# Downloading redis-5.3.1-py3-none-any.whl (272 kB)
# Using cached redisvl-0.8.0-py3-none-any.whl (152 kB)
# Downloading alembic-1.16.4-py3-none-any.whl (247 kB)
# Using cached jsonpath_ng-1.7.0-py3-none-any.whl (30 kB)
# Downloading ml_dtypes-0.5.3-cp312-cp312-macosx_10_13_universal2.whl (663 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 kB 27.4 MB/s eta 0:00:00
# Using cached numba-0.61.2-cp312-cp312-macosx_11_0_arm64.whl (2.8 MB)
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl (1.8 MB)
# Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached python_ulid-3.0.0-py3-none-any.whl (11 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached PyYAML-6.0.2-cp312-cp312-macosx_11_0_arm64.whl (173 kB)
# Downloading regex-2025.7.34-cp312-cp312-macosx_11_0_arm64.whl (286 kB)
# Downloading scipy-1.16.1-cp312-cp312-macosx_14_0_arm64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 49.9 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading sqlalchemy-2.0.42-cp312-cp312-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 48.3 MB/s eta 0:00:00
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached cbor2-5.6.5-cp312-cp312-macosx_11_0_arm64.whl (67 kB)
# Using cached click-8.2.1-py3-none-any.whl (102 kB)
# Using cached colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading datasets-4.0.0-py3-none-any.whl (494 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached fastparquet-2024.11.0-cp312-cp312-macosx_11_0_arm64.whl (685 kB)
# Using cached ir_datasets-0.5.11-py3-none-any.whl (866 kB)
# Using cached lz4-4.4.4-cp312-cp312-macosx_11_0_arm64.whl (189 kB)
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading orjson-3.11.1-cp312-cp312-macosx_15_0_arm64.whl (129 kB)
# Using cached pytrec_eval_terrier-0.5.7-cp312-cp312-macosx_10_13_universal2.whl (135 kB)
# Downloading rich-14.1.0-py3-none-any.whl (243 kB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached sentence_transformers-5.0.0-py3-none-any.whl (470 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Downloading cramjam-2.11.0-cp312-cp312-macosx_11_0_arm64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 54.7 MB/s eta 0:00:00
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Downloading huggingface_hub-0.34.3-py3-none-any.whl (558 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 558.8/558.8 kB 26.1 MB/s eta 0:00:00
# Using cached ijson-3.4.0-cp312-cp312-macosx_11_0_arm64.whl (59 kB)
# Using cached inscriptis-2.6.0-py3-none-any.whl (45 kB)
# Using cached llvmlite-0.44.0-cp312-cp312-macosx_11_0_arm64.whl (26.2 MB)
# Using cached lxml-6.0.0-cp312-cp312-macosx_10_13_universal2.whl (8.4 MB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading matplotlib-3.10.5-cp312-cp312-macosx_11_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 54.8 MB/s eta 0:00:00
# Using cached multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Using cached pillow-11.3.0-cp312-cp312-macosx_11_0_arm64.whl (4.7 MB)
# Downloading pyarrow-21.0.0-cp312-cp312-macosx_12_0_arm64.whl (31.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.2/31.2 MB 51.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading pygments-2.19.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 36.5 MB/s eta 0:00:00
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached torch-2.7.1-cp312-none-macosx_11_0_arm64.whl (68.6 MB)
# Downloading transformers-4.54.1-py3-none-any.whl (11.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 51.0 MB/s eta 0:00:0031m52.9 MB/s eta 0:00:01
# Using cached trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Downloading typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Using cached unlzw3-0.2.3-py3-none-any.whl (6.7 kB)
# Using cached warc3_wet-0.2.5-py3-none-any.whl (18 kB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached mako-1.3.10-py3-none-any.whl (78 kB)
# Using cached ply-3.11-py2.py3-none-any.whl (49 kB)
# Downloading scikit_learn-1.7.1-cp312-cp312-macosx_12_0_arm64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 40.0 MB/s eta 0:00:0031m42.8 MB/s eta 0:00:01
# Using cached xxhash-3.5.0-cp312-cp312-macosx_11_0_arm64.whl (30 kB)
# Downloading aiohttp-3.12.15-cp312-cp312-macosx_11_0_arm64.whl (469 kB)
# Downloading certifi-2025.7.14-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.4.2-cp312-cp312-macosx_10_13_universal2.whl (199 kB)
# Downloading contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl (273 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.0-cp312-cp312-macosx_10_13_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 45.0 MB/s eta 0:00:00
# Using cached hf_xet-1.1.5-cp37-abi3-macosx_11_0_arm64.whl (2.6 MB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached kiwisolver-1.4.8-cp312-cp312-macosx_11_0_arm64.whl (65 kB)
# Using cached MarkupSafe-3.0.2-cp312-cp312-macosx_11_0_arm64.whl (12 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Using cached safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl (418 kB)
# Using cached soupsieve-2.7-py3-none-any.whl (36 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tokenizers-0.21.4-cp39-abi3-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 27.7 MB/s eta 0:00:00
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached networkx-3.5-py3-none-any.whl (2.0 MB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached frozenlist-1.7.0-cp312-cp312-macosx_11_0_arm64.whl (46 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached multidict-6.6.3-cp312-cp312-macosx_11_0_arm64.whl (43 kB)
# Using cached propcache-0.3.2-cp312-cp312-macosx_11_0_arm64.whl (43 kB)
# Using cached yarl-1.20.1-cp312-cp312-macosx_11_0_arm64.whl (89 kB)
# Installing collected packages: warc3-wet-clueweb09, warc3-wet, pytz, ply, mpmath, cbor, zlib-state, xxhash, urllib3, unlzw3, tzdata, typing-extensions, tqdm, threadpoolctl, tenacity, tabulate, sympy, soupsieve, six, setuptools, safetensors, regex, PyYAML, pytrec-eval-terrier, python-ulid, python-dotenv, pyparsing, PyJWT, pygments, pyarrow, propcache, Pillow, packaging, orjson, numpy, networkx, multidict, mdurl, MarkupSafe, lz4, lxml, llvmlite, kiwisolver, jsonpath-ng, joblib, ijson, idna, hf-xet, fsspec, frozenlist, fonttools, filelock, dill, cycler, cramjam, colorlog, click, charset_normalizer, certifi, cbor2, attrs, annotated-types, aiohappyeyeballs, yarl, typing-inspection, trec-car-tools, sqlalchemy, scipy, requests, redis, python-dateutil, pydantic-core, numba, nltk, multiprocess, ml-dtypes, markdown-it-py, Mako, jinja2, contourpy, beautifulsoup4, aiosignal, torch, scikit-learn, rich, pydantic, pandas, matplotlib, inscriptis, huggingface-hub, alembic, aiohttp, tokenizers, seaborn, redisvl, optuna, ir-datasets, fastparquet, transformers, ranx, datasets, sentence-transformers, beir, redis-retrieval-optimizer
#   Attempting uninstall: warc3-wet-clueweb09
#     Found existing installation: warc3-wet-clueweb09 0.2.5
#     Uninstalling warc3-wet-clueweb09-0.2.5:
#       Successfully uninstalled warc3-wet-clueweb09-0.2.5
#   Attempting uninstall: warc3-wet
#     Found existing installation: warc3-wet 0.2.5
#     Uninstalling warc3-wet-0.2.5:
#       Successfully uninstalled warc3-wet-0.2.5
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: ply
#     Found existing installation: ply 3.11
#     Uninstalling ply-3.11:
#       Successfully uninstalled ply-3.11
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: cbor
#     Found existing installation: cbor 1.0.0
#     Uninstalling cbor-1.0.0:
#       Successfully uninstalled cbor-1.0.0
#   Attempting uninstall: zlib-state
#     Found existing installation: zlib-state 0.1.9
#     Uninstalling zlib-state-0.1.9:
#       Successfully uninstalled zlib-state-0.1.9
#   Attempting uninstall: xxhash
#     Found existing installation: xxhash 3.5.0
#     Uninstalling xxhash-3.5.0:
#       Successfully uninstalled xxhash-3.5.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: unlzw3
#     Found existing installation: unlzw3 0.2.3
#     Uninstalling unlzw3-0.2.3:
#       Successfully uninstalled unlzw3-0.2.3
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.2
#     Uninstalling tzdata-2025.2:
#       Successfully uninstalled tzdata-2025.2
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.13.2
#     Uninstalling typing_extensions-4.13.2:
#       Successfully uninstalled typing_extensions-4.13.2
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.6.0
#     Uninstalling threadpoolctl-3.6.0:
#       Successfully uninstalled threadpoolctl-3.6.0
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.5.0
#     Uninstalling tenacity-8.5.0:
#       Successfully uninstalled tenacity-8.5.0
#   Attempting uninstall: tabulate
#     Found existing installation: tabulate 0.9.0
#     Uninstalling tabulate-0.9.0:
#       Successfully uninstalled tabulate-0.9.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:
#       Successfully uninstalled sympy-1.14.0
#   Attempting uninstall: soupsieve
#     Found existing installation: soupsieve 2.7
#     Uninstalling soupsieve-2.7:
#       Successfully uninstalled soupsieve-2.7
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 80.9.0
#     Uninstalling setuptools-80.9.0:
#       Successfully uninstalled setuptools-80.9.0
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.5.3
#     Uninstalling safetensors-0.5.3:
#       Successfully uninstalled safetensors-0.5.3
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.11.6
#     Uninstalling regex-2024.11.6:
#       Successfully uninstalled regex-2024.11.6
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
#   Attempting uninstall: pytrec-eval-terrier
#     Found existing installation: pytrec_eval-terrier 0.5.7
#     Uninstalling pytrec_eval-terrier-0.5.7:
#       Successfully uninstalled pytrec_eval-terrier-0.5.7
#   Attempting uninstall: python-ulid
#     Found existing installation: python-ulid 3.0.0
#     Uninstalling python-ulid-3.0.0:
#       Successfully uninstalled python-ulid-3.0.0
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.1.0
#     Uninstalling python-dotenv-1.1.0:
#       Successfully uninstalled python-dotenv-1.1.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.2.3
#     Uninstalling pyparsing-3.2.3:
#       Successfully uninstalled pyparsing-3.2.3
#   Attempting uninstall: PyJWT
#     Found existing installation: PyJWT 2.9.0
#     Uninstalling PyJWT-2.9.0:
#       Successfully uninstalled PyJWT-2.9.0
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.19.1
#     Uninstalling Pygments-2.19.1:
#       Successfully uninstalled Pygments-2.19.1
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 17.0.0
#     Uninstalling pyarrow-17.0.0:
#       Successfully uninstalled pyarrow-17.0.0
#   Attempting uninstall: propcache
#     Found existing installation: propcache 0.3.2
#     Uninstalling propcache-0.3.2:
#       Successfully uninstalled propcache-0.3.2
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: orjson
#     Found existing installation: orjson 3.10.18
#     Uninstalling orjson-3.10.18:
#       Successfully uninstalled orjson-3.10.18
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.5
#     Uninstalling networkx-3.5:
#       Successfully uninstalled networkx-3.5
#   Attempting uninstall: multidict
#     Found existing installation: multidict 6.6.3
#     Uninstalling multidict-6.6.3:
#       Successfully uninstalled multidict-6.6.3
#   Attempting uninstall: mdurl
#     Found existing installation: mdurl 0.1.2
#     Uninstalling mdurl-0.1.2:
#       Successfully uninstalled mdurl-0.1.2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: lz4
#     Found existing installation: lz4 4.4.4
#     Uninstalling lz4-4.4.4:
#       Successfully uninstalled lz4-4.4.4
#   Attempting uninstall: lxml
#     Found existing installation: lxml 6.0.0
#     Uninstalling lxml-6.0.0:
#       Successfully uninstalled lxml-6.0.0
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.44.0
#     Uninstalling llvmlite-0.44.0:
#       Successfully uninstalled llvmlite-0.44.0
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.4.8
#     Uninstalling kiwisolver-1.4.8:
#       Successfully uninstalled kiwisolver-1.4.8
#   Attempting uninstall: jsonpath-ng
#     Found existing installation: jsonpath-ng 1.7.0
#     Uninstalling jsonpath-ng-1.7.0:
#       Successfully uninstalled jsonpath-ng-1.7.0
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.5.1
#     Uninstalling joblib-1.5.1:
#       Successfully uninstalled joblib-1.5.1
#   Attempting uninstall: ijson
#     Found existing installation: ijson 3.4.0
#     Uninstalling ijson-3.4.0:
#       Successfully uninstalled ijson-3.4.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: hf-xet
#     Found existing installation: hf-xet 1.1.5
#     Uninstalling hf-xet-1.1.5:
#       Successfully uninstalled hf-xet-1.1.5
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: frozenlist
#     Found existing installation: frozenlist 1.7.0
#     Uninstalling frozenlist-1.7.0:
#       Successfully uninstalled frozenlist-1.7.0
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.58.5
#     Uninstalling fonttools-4.58.5:
#       Successfully uninstalled fonttools-4.58.5
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.16.1
#     Uninstalling filelock-3.16.1:
#       Successfully uninstalled filelock-3.16.1
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.8
#     Uninstalling dill-0.3.8:
#       Successfully uninstalled dill-0.3.8
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: cramjam
#     Found existing installation: cramjam 2.10.0
#     Uninstalling cramjam-2.10.0:
#       Successfully uninstalled cramjam-2.10.0
#   Attempting uninstall: colorlog
#     Found existing installation: colorlog 6.9.0
#     Uninstalling colorlog-6.9.0:
#       Successfully uninstalled colorlog-6.9.0
#   Attempting uninstall: click
#     Found existing installation: click 8.2.1
#     Uninstalling click-8.2.1:
#       Successfully uninstalled click-8.2.1
#   Attempting uninstall: charset_normalizer
#     Found existing installation: charset-normalizer 3.4.1
#     Uninstalling charset-normalizer-3.4.1:
#       Successfully uninstalled charset-normalizer-3.4.1
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.12.14
#     Uninstalling certifi-2024.12.14:
#       Successfully uninstalled certifi-2024.12.14
#   Attempting uninstall: cbor2
#     Found existing installation: cbor2 5.6.5
#     Uninstalling cbor2-5.6.5:
#       Successfully uninstalled cbor2-5.6.5
#   Attempting uninstall: attrs
#     Found existing installation: attrs 25.3.0
#     Uninstalling attrs-25.3.0:
#       Successfully uninstalled attrs-25.3.0
#   Attempting uninstall: annotated-types
#     Found existing installation: annotated-types 0.7.0
#     Uninstalling annotated-types-0.7.0:
#       Successfully uninstalled annotated-types-0.7.0
#   Attempting uninstall: aiohappyeyeballs
#     Found existing installation: aiohappyeyeballs 2.6.1
#     Uninstalling aiohappyeyeballs-2.6.1:
#       Successfully uninstalled aiohappyeyeballs-2.6.1
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.20.1
#     Uninstalling yarl-1.20.1:
#       Successfully uninstalled yarl-1.20.1
#   Attempting uninstall: trec-car-tools
#     Found existing installation: trec-car-tools 2.6
#     Uninstalling trec-car-tools-2.6:
#       Successfully uninstalled trec-car-tools-2.6
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.41
#     Uninstalling SQLAlchemy-2.0.41:
#       Successfully uninstalled SQLAlchemy-2.0.41
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.3
#     Uninstalling scipy-1.15.3:
#       Successfully uninstalled scipy-1.15.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: redis
#     Found existing installation: redis 5.3.0
#     Uninstalling redis-5.3.0:
#       Successfully uninstalled redis-5.3.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.27.2
#     Uninstalling pydantic_core-2.27.2:
#       Successfully uninstalled pydantic_core-2.27.2
#   Attempting uninstall: numba
#     Found existing installation: numba 0.61.2
#     Uninstalling numba-0.61.2:
#       Successfully uninstalled numba-0.61.2
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.9.1
#     Uninstalling nltk-3.9.1:
#       Successfully uninstalled nltk-3.9.1
#   Attempting uninstall: multiprocess
#     Found existing installation: multiprocess 0.70.16
#     Uninstalling multiprocess-0.70.16:
#       Successfully uninstalled multiprocess-0.70.16
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml_dtypes 0.5.1
#     Uninstalling ml_dtypes-0.5.1:
#       Successfully uninstalled ml_dtypes-0.5.1
#   Attempting uninstall: markdown-it-py
#     Found existing installation: markdown-it-py 3.0.0
#     Uninstalling markdown-it-py-3.0.0:
#       Successfully uninstalled markdown-it-py-3.0.0
#   Attempting uninstall: Mako
#     Found existing installation: Mako 1.3.10
#     Uninstalling Mako-1.3.10:
#       Successfully uninstalled Mako-1.3.10
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.6
#     Uninstalling Jinja2-3.1.6:
#       Successfully uninstalled Jinja2-3.1.6
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.3.2
#     Uninstalling contourpy-1.3.2:
#       Successfully uninstalled contourpy-1.3.2
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.13.4
#     Uninstalling beautifulsoup4-4.13.4:
#       Successfully uninstalled beautifulsoup4-4.13.4
#   Attempting uninstall: aiosignal
#     Found existing installation: aiosignal 1.3.2
#     Uninstalling aiosignal-1.3.2:
#       Successfully uninstalled aiosignal-1.3.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.7.1
#     Uninstalling torch-2.7.1:
#       Successfully uninstalled torch-2.7.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
#   Attempting uninstall: rich
#     Found existing installation: rich 14.0.0
#     Uninstalling rich-14.0.0:
#       Successfully uninstalled rich-14.0.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.6
#     Uninstalling pydantic-2.10.6:
#       Successfully uninstalled pydantic-2.10.6
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.3
#     Uninstalling matplotlib-3.10.3:
#       Successfully uninstalled matplotlib-3.10.3
#   Attempting uninstall: inscriptis
#     Found existing installation: inscriptis 2.6.0
#     Uninstalling inscriptis-2.6.0:
#       Successfully uninstalled inscriptis-2.6.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.33.2
#     Uninstalling huggingface-hub-0.33.2:
#       Successfully uninstalled huggingface-hub-0.33.2
#   Attempting uninstall: alembic
#     Found existing installation: alembic 1.16.2
#     Uninstalling alembic-1.16.2:
#       Successfully uninstalled alembic-1.16.2
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.12.13
#     Uninstalling aiohttp-3.12.13:
#       Successfully uninstalled aiohttp-3.12.13
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.2
#     Uninstalling tokenizers-0.21.2:
#       Successfully uninstalled tokenizers-0.21.2
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.2
#     Uninstalling seaborn-0.13.2:
#       Successfully uninstalled seaborn-0.13.2
#   Attempting uninstall: redisvl
#     Found existing installation: redisvl 0.8.0
#     Uninstalling redisvl-0.8.0:
#       Successfully uninstalled redisvl-0.8.0
#   Attempting uninstall: optuna
#     Found existing installation: optuna 4.4.0
#     Uninstalling optuna-4.4.0:
#       Successfully uninstalled optuna-4.4.0
#   Attempting uninstall: ir-datasets
#     Found existing installation: ir_datasets 0.5.11
#     Uninstalling ir_datasets-0.5.11:
#       Successfully uninstalled ir_datasets-0.5.11
#   Attempting uninstall: fastparquet
#     Found existing installation: fastparquet 2024.11.0
#     Uninstalling fastparquet-2024.11.0:
#       Successfully uninstalled fastparquet-2024.11.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.53.0
#     Uninstalling transformers-4.53.0:
#       Successfully uninstalled transformers-4.53.0
#   Attempting uninstall: ranx
#     Found existing installation: ranx 0.3.20
#     Uninstalling ranx-0.3.20:
#       Successfully uninstalled ranx-0.3.20
#   Attempting uninstall: datasets
#     Found existing installation: datasets 3.6.0
#     Uninstalling datasets-3.6.0:
#       Successfully uninstalled datasets-3.6.0
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 5.0.0
#     Uninstalling sentence-transformers-5.0.0:
#       Successfully uninstalled sentence-transformers-5.0.0
#   Attempting uninstall: beir
#     Found existing installation: beir 2.2.0
#     Uninstalling beir-2.2.0:
#       Successfully uninstalled beir-2.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# feast 0.49.0 requires pyarrow<=17.0.0, but you have pyarrow 21.0.0 which is incompatible.
# feast 0.49.0 requires pydantic==2.10.6, but you have pydantic 2.11.7 which is incompatible.
# feast 0.49.0 requires tenacity<9,>=7, but you have tenacity 9.1.2 which is incompatible.
# Successfully installed Mako-1.3.10 MarkupSafe-3.0.2 Pillow-11.3.0 PyJWT-2.10.1 PyYAML-6.0.2 aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 alembic-1.16.4 annotated-types-0.7.0 attrs-25.3.0 beautifulsoup4-4.13.4 beir-2.2.0 cbor-1.0.0 cbor2-5.6.5 certifi-2025.7.14 charset_normalizer-3.4.2 click-8.2.1 colorlog-6.9.0 contourpy-1.3.3 cramjam-2.11.0 cycler-0.12.1 datasets-4.0.0 dill-0.3.8 fastparquet-2024.11.0 filelock-3.18.0 fonttools-4.59.0 frozenlist-1.7.0 fsspec-2025.3.0 hf-xet-1.1.5 huggingface-hub-0.34.3 idna-3.10 ijson-3.4.0 inscriptis-2.6.0 ir-datasets-0.5.11 jinja2-3.1.6 joblib-1.5.1 jsonpath-ng-1.7.0 kiwisolver-1.4.8 llvmlite-0.44.0 lxml-6.0.0 lz4-4.4.4 markdown-it-py-3.0.0 matplotlib-3.10.5 mdurl-0.1.2 ml-dtypes-0.5.3 mpmath-1.3.0 multidict-6.6.3 multiprocess-0.70.16 networkx-3.5 nltk-3.9.1 numba-0.61.2 numpy-1.26.4 optuna-4.4.0 orjson-3.11.1 packaging-25.0 pandas-2.3.1 ply-3.11 propcache-0.3.2 pyarrow-21.0.0 pydantic-2.11.7 pydantic-core-2.33.2 pygments-2.19.2 pyparsing-3.2.3 python-dateutil-2.9.0.post0 python-dotenv-1.1.1 python-ulid-3.0.0 pytrec-eval-terrier-0.5.7 pytz-2025.2 ranx-0.3.20 redis-5.3.1 redis-retrieval-optimizer-0.3.0 redisvl-0.8.0 regex-2025.7.34 requests-2.32.4 rich-14.1.0 safetensors-0.5.3 scikit-learn-1.7.1 scipy-1.16.1 seaborn-0.13.2 sentence-transformers-5.0.0 setuptools-80.9.0 six-1.17.0 soupsieve-2.7 sqlalchemy-2.0.42 sympy-1.14.0 tabulate-0.9.0 tenacity-9.1.2 threadpoolctl-3.6.0 tokenizers-0.21.4 torch-2.7.1 tqdm-4.67.1 transformers-4.54.1 trec-car-tools-2.6 typing-extensions-4.14.1 typing-inspection-0.4.1 tzdata-2025.2 unlzw3-0.2.3 urllib3-2.5.0 warc3-wet-0.2.5 warc3-wet-clueweb09-0.2.5 xxhash-3.5.0 yarl-1.20.1 zlib-state-0.1.9
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from redis_retrieval_optimizer.search_study import run_search_study

SEARCH_METHOD_MAP = {
    "base_vector": gather_vector_results,
    "pre_filter_vector": gather_pre_filter_results
}

metrics = run_search_study(
    config_path="search_study_config.yaml",
    redis_url=redis_url,
    search_method_map=SEARCH_METHOD_MAP
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 from redis_retrieval_optimizer.search_study import run_search_study
#       3 SEARCH_METHOD_MAP = {
#       4     "base_vector": gather_vector_results,
#       5     "pre_filter_vector": gather_pre_filter_results
#       6 }
#       8 metrics = run_search_study(
#       9     config_path="search_study_config.yaml",
#      10     redis_url=redis_url,
#      11     search_method_map=SEARCH_METHOD_MAP
#      12 )
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/site-packages/redis_retrieval_optimizer/search_study.py:7
#       4 from redis.commands.json.path import Path
#       5 from redisvl.index import SearchIndex
# ----> 7 import redis_retrieval_optimizer.utils as utils
#       8 from redis_retrieval_optimizer.schema import SearchMethodInput, SearchStudyConfig
#       9 from redis_retrieval_optimizer.search_methods import SEARCH_METHOD_MAP
#
# File ~/.pyenv/versions/3.12.8/lib/python3.12/site-packages/redis_retrieval_optimizer/utils.py:22
#      19 from redisvl.utils.vectorize.text.vertexai import VertexAITextVectorizer
#      20 from redisvl.utils.vectorize.text.voyageai import VoyageAITextVectorizer
# ---> 22 from redis_retrieval_optimizer.schema import (
#      23     BayesStudyConfig,
#      24     EmbeddingModel,
#      25     GridStudyConfig,
#      26     IndexSettings,
#      27     SearchStudyConfig,
#      28 )
#      31 def vectorizer_from_dict(
#      32     vectorizer: dict,
#      33     cache: dict = {},
#      34 ) -> BaseVectorizer:
#      35     vectorizer_type = Vectorizers(vectorizer["type"])
#
# ImportError: cannot import name 'SearchStudyConfig' from 'redis_retrieval_optimizer.schema' (/Users/robert.shelton/.pyenv/versions/3.12.8/lib/python3.12/site-packages/redis_retrieval_optimizer/schema.py)

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall redis-retrieval-optimizer -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: redis-retrieval-optimizer 0.3.0
# Uninstalling redis-retrieval-optimizer-0.3.0:
#   Successfully uninstalled redis-retrieval-optimizer-0.3.0
# Note: you may need to restart the kernel to use updated packages.
