# %% [markdown]
# # Search study
#
# Let's say you have an existing Redis database with a search index seeded. You may wish to quickly test different search method against the existing index without having to recreate data and/or recreate the index. This demo will walk you though how to set this up and get going.
#
# # Installation

# %%
# %pip install redis-retrieval-optimizer

# %% [markdown]
# ## Check markdown

# %%
import redis_retrieval_optimizer

redis_retrieval_optimizer.__version__
# Out:
# '0.4.1'

# %% [markdown]
# # Load data
#
# We will load our custom car dataset for this example.

# %%
import json

with open('../resources/cars/car_corpus.json', 'r') as f:
    corpus = json.load(f)

with open('../resources/cars/car_queries.json', 'r') as f:
    queries = json.load(f)

with open('../resources/cars/car_qrels.json', 'r') as f:
    qrels = json.load(f)

# %% [markdown]
# # Create the index with redisvl
#
# For the search_study we are assuming that the search index already exists. The cell below will create a Redis search index and populate it with our test data for example purposes but is assumed with a search study is populated and running within your data.
#
# Note: the demo assumes you have a instance of redis running on localhost:6379. If this is not the case, update the redis_url to direct to your running instance or start a local instance with the following command.
#
# `docker run -d --name redis-stack-server -p 6379:6379 redis/redis-stack-server:latest`

# %%
# assuming you have a redis instance running on localhost:6379
redis_url = "redis://localhost:6379"

# %%
from redisvl.index import SearchIndex
from redisvl.utils.vectorize import HFTextVectorizer

emb_model = HFTextVectorizer()

# define schema
car_schema = {
    "index": {
        "name": "cars",
        "prefix": "cars"
    },
    "fields": [
        {"name": "item_id", "type": "tag"},
        {"name": "text", "type": "text"},
        {"name": "make", "type": "tag"},
        {"name": "model", "type": "tag"},
        {
            "name": "vector",
            "type": "vector",
            "attrs": {
                "dims": 768,
                "distance_metric": "cosine",
                "algorithm": "FLAT",
                "datatype": "float32"
            },
        },
    ]
}

# create index
index = SearchIndex.from_dict(car_schema, redis_url=redis_url)
index.create(overwrite=True)

embeddings = emb_model.embed_many([c["text"] for c in corpus], as_buffer=True)

# vectorize corpus data
corpus_data = [
    {
        "text": c["text"],
        "item_id": c["item_id"],
        "make": c["query_metadata"]["make"],
        "model": c["query_metadata"]["model"],
        "vector": embeddings[i]
    }
    for i, c in enumerate(corpus)
]

index.load(corpus_data)
# Out:
# 15:06:21 datasets INFO   PyTorch version 2.3.0 available.
# 15:06:21 sentence_transformers.SentenceTransformer INFO   Use pytorch device_name: mps
# 15:06:21 sentence_transformers.SentenceTransformer INFO   Load pretrained SentenceTransformer: sentence-transformers/all-mpnet-base-v2
# ['cars:01K3KWCRBPQ293ENR2HS3GEWR6',
#  'cars:01K3KWCRBPBG49PSRYAH6M12VQ',
#  'cars:01K3KWCRBPT2D3APPF093BXRJ9',
#  'cars:01K3KWCRBPZNQX33WSW300WX6F',
#  'cars:01K3KWCRBPVZC0Z3KMK6EKWWDV',
#  'cars:01K3KWCRBP4G9VHHXAPE2BFYR3',
#  'cars:01K3KWCRBP3TFADF56PE9Q8W84',
#  'cars:01K3KWCRBP1BSCG9AFK2NXWNFZ',
#  'cars:01K3KWCRBPST6M371T471VV3C9',
#  'cars:01K3KWCRBP4ASBVN26QB1CFKS8',
#  'cars:01K3KWCRBPF10S5KYA5R2MBMBP',
#  'cars:01K3KWCRBPRRHC8F307E9KR87W',
#  'cars:01K3KWCRBP1P82DECES6EZD5HF',
#  'cars:01K3KWCRBPXYBFDBPA7QN50WVR',
#  'cars:01K3KWCRBPW9KJ520HP9NQR64D',
#  'cars:01K3KWCRBPT8A895SGWWZ5A5BV',
#  'cars:01K3KWCRBPQFH43196CQ60YTGB',
#  'cars:01K3KWCRBPPF88ZM6K8JXW434R',
#  'cars:01K3KWCRBPB5DWDJQND33DC8NS',
#  'cars:01K3KWCRBPV87CE2ADVPHN992H',
#  'cars:01K3KWCRBP4SJZCP3SV318H4Y9',
#  'cars:01K3KWCRBP2FW4AEVQ2SEHD1BK',
#  'cars:01K3KWCRBPK11AZKCWY2HTBC6Y',
#  'cars:01K3KWCRBPBB7FRRMJJFQK0655',
#  'cars:01K3KWCRBPFB7ZRV8ZJSET4ZG9',
#  'cars:01K3KWCRBPPW648R9FEZS63GSS',
#  'cars:01K3KWCRBPD25R873Q9V2M174J',
#  'cars:01K3KWCRBPT55486M2Q7M9CXVE',
#  'cars:01K3KWCRBP67J8VQ1E93SSFHZG',
#  'cars:01K3KWCRBPGHSJTWC0JHF0XQ5K',
#  'cars:01K3KWCRBPN5NYK0FGM8HQRQ84',
#  'cars:01K3KWCRBP7JBPEESM73GZ3KNA',
#  'cars:01K3KWCRBPE35TFEYSQF9TN30K',
#  'cars:01K3KWCRBPEG2EXTWFYDS1CDS3',
#  'cars:01K3KWCRBP3RR0PPN3Y3VE9MTQ',
#  'cars:01K3KWCRBPRZ8VZYXS3C60F46Z',
#  'cars:01K3KWCRBP5D3SK330E39AVSVA',
#  'cars:01K3KWCRBPNVRVMJBBV7NSZJQW',
#  'cars:01K3KWCRBPQT6DMKH87GEBJQ1C',
#  'cars:01K3KWCRBPZ3ENVZ7K64FCHP84',
#  'cars:01K3KWCRBPT5JC1TFH985QN7XC',
#  'cars:01K3KWCRBP6KT41W5Y4W7Y35DJ',
#  'cars:01K3KWCRBPRQG3J70FCTPAKESS',
#  'cars:01K3KWCRBPY4FXBKQ3HSP21JQQ',
#  'cars:01K3KWCRBP1JRK7JKEGMHQKQA5',
#  'cars:01K3KWCRBPT05GQTVA739M62KJ',
#  'cars:01K3KWCRBPBS53G0XAFH8VTFM3',
#  'cars:01K3KWCRBPBN8Z1GBTXAVETN2K',
#  'cars:01K3KWCRBPPMGX7N57S2HHPKZH',
#  'cars:01K3KWCRBP4JEFZ1VNQHRAXNC5',
#  'cars:01K3KWCRBPWN7WTPBECVXZJZAC',
#  'cars:01K3KWCRBPFYJP4H7G1WN15HN1',
#  'cars:01K3KWCRBPAEJ1FVN9RDXYFDG9',
#  'cars:01K3KWCRBPPN1SFVWPBY2QTH98',
#  'cars:01K3KWCRBPQ0ZJA6PTPXA96P5Y',
#  'cars:01K3KWCRBPW98JXVK8JMBHAGWV',
#  'cars:01K3KWCRBPG7E559ZM0MDVH8XV',
#  'cars:01K3KWCRBPSWDVR9B4GFEHN3MF',
#  'cars:01K3KWCRBP2JK1MAFS4JHV2S7J',
#  'cars:01K3KWCRBPDN3RQQ8Z0EX1696P',
#  'cars:01K3KWCRBP3E3TGZ3G466Z4FYR',
#  'cars:01K3KWCRBPBMNEYCJPCMC4A32S',
#  'cars:01K3KWCRBP4S8VP43J6Q6RC6DP',
#  'cars:01K3KWCRBP3684CHC7B8XE8A2C',
#  'cars:01K3KWCRBP20M2YYXTX53CQZHY',
#  'cars:01K3KWCRBPQ1K2HMFBDWPEQNG3',
#  'cars:01K3KWCRBPSJ1JCR3JPHM78ACE',
#  'cars:01K3KWCRBP06YD43PGVDF5YHG7',
#  'cars:01K3KWCRBP87A1ZEFC5V92DJXF',
#  'cars:01K3KWCRBPKYEMSBRH4XB1QTWH',
#  'cars:01K3KWCRBP7XA8JK28MX4P7SJH',
#  'cars:01K3KWCRBPE85ASFQ93X2Q530Q',
#  'cars:01K3KWCRBPYJB7P67474SREFQG',
#  'cars:01K3KWCRBP91DCHPC3Q9TYY91K',
#  'cars:01K3KWCRBP9T4QHZG35P18BADW',
#  'cars:01K3KWCRBPXZWGJVJE5CEEZ3W3',
#  'cars:01K3KWCRBPV6BB8CPMH68ECKJR',
#  'cars:01K3KWCRBPKMCVQT9DS7GG2EGW',
#  'cars:01K3KWCRBPPM64FX8JS1MFFP74',
#  'cars:01K3KWCRBP4K1R90GQC8BY22M3',
#  'cars:01K3KWCRBPFSGXYSHAFABQTTZ3',
#  'cars:01K3KWCRBPHP94QF33SR8HEJK6',
#  'cars:01K3KWCRBPYVCMT02TJGR06721',
#  'cars:01K3KWCRBP9VJQCBZBD24VYQK7',
#  'cars:01K3KWCRBPWXK1DJARMDN3VEQF',
#  'cars:01K3KWCRBPV33KN9Y330YJJV66',
#  'cars:01K3KWCRBPW632N239DJTSAFBV',
#  'cars:01K3KWCRBPKHQ0D9PD4H5VCQ7Y',
#  'cars:01K3KWCRBP08VSXKEH5CVMJZAH',
#  'cars:01K3KWCRBPV4ZJARTPW4CCP4KT',
#  'cars:01K3KWCRBPH7N6QFM8W38HGA3F',
#  'cars:01K3KWCRBPGNTXKP9CNPFDVJCY',
#  'cars:01K3KWCRBPT075SCNZ205TQ3BJ',
#  'cars:01K3KWCRBP73E2G840WNMNNZ37',
#  'cars:01K3KWCRBPQAT7TDYA6W63C346',
#  'cars:01K3KWCRBPV816X75AH5DQXY4B',
#  'cars:01K3KWCRBP2G16TTTCA7TNB42Q',
#  'cars:01K3KWCRBPZ2AHYF4TJ3C5NC45',
#  'cars:01K3KWCRBPNT7TMMGSPQPWV1SY',
#  'cars:01K3KWCRBP7TBP76ZMGT5SC2YX',
#  'cars:01K3KWCRBP8WM8Q1WV6C81GM0M',
#  'cars:01K3KWCRBPFEYGBTP1KT6TAGQH',
#  'cars:01K3KWCRBPSZGPDXQ20XPCQ19J',
#  'cars:01K3KWCRBPPHKDZN7MQBGGVRF7',
#  'cars:01K3KWCRBPWC7FD54XJF09C9NE',
#  'cars:01K3KWCRBP0K9TB6MDC6A9GYPB',
#  'cars:01K3KWCRBP49YVS5TP6J240M38',
#  'cars:01K3KWCRBP1E5BV64BVEN9SV24',
#  'cars:01K3KWCRBP0GJPTHW2P54MPCPP',
#  'cars:01K3KWCRBPFGWD0HW4CJGY5XH1',
#  'cars:01K3KWCRBPX1RTMQ5BPMESRS4A',
#  'cars:01K3KWCRBP9W93G95D0A9WGARK',
#  'cars:01K3KWCRBPTJ808P3R3Q5S3KCB',
#  'cars:01K3KWCRBPHB0ZRF1SNS30HRPD',
#  'cars:01K3KWCRBPCZ51FJVG12957GS2',
#  'cars:01K3KWCRBPQC70C96WFPEW7WZT',
#  'cars:01K3KWCRBPZNK3MZSZMH1AZC3Z',
#  'cars:01K3KWCRBPHY7H63B7H0S44YVY',
#  'cars:01K3KWCRBPK6M1WBFSYPAZQ91Y',
#  'cars:01K3KWCRBPB0A2W0QQGH4E9PHW',
#  'cars:01K3KWCRBPBX7HN2QTZG1TECY0',
#  'cars:01K3KWCRBP9B6T18GT9CCFJNG8',
#  'cars:01K3KWCRBP7CMQA3NV9R3K5VX3',
#  'cars:01K3KWCRBPN4085M7KTCHHG2QS',
#  'cars:01K3KWCRBPTQJXGPQKA0M9BX6R',
#  'cars:01K3KWCRBPQ36RPPEM7ABPX8G2',
#  'cars:01K3KWCRBPPVYRQDJCNANQSQPC',
#  'cars:01K3KWCRBPMP827CH9HECGAW6P',
#  'cars:01K3KWCRBPCC9CKRFBB8FCSR12',
#  'cars:01K3KWCRBP14NB82KNH9VYS4DD',
#  'cars:01K3KWCRBPVA5BQCPW1SA5W7CH',
#  'cars:01K3KWCRBPMXHGKJC1AZSGQXQZ',
#  'cars:01K3KWCRBP8DMKW6YK1171FNB9',
#  'cars:01K3KWCRBPW5RC5NG7ESTBPNXZ',
#  'cars:01K3KWCRBP93GNZBKP8V3E8QNJ',
#  'cars:01K3KWCRBP8T2GH286SHT00RPR',
#  'cars:01K3KWCRBPYCQ3WPFZFRXZ3BNH',
#  'cars:01K3KWCRBPEWBCZB22NRNVMBEZ',
#  'cars:01K3KWCRBPGHZW6H6W6NEE1BK0',
#  'cars:01K3KWCRBPKAY94AYSF85FG6G8',
#  'cars:01K3KWCRBPCCTHA130Q4KQSSGY',
#  'cars:01K3KWCRBPFVHDWHV6X9P0NJA2',
#  'cars:01K3KWCRBPKWC3QQBW4Z6NTPTT',
#  'cars:01K3KWCRBPVC0Z18M34PEDDK89',
#  'cars:01K3KWCRBPWF3VKFZ775WGGJTR',
#  'cars:01K3KWCRBPXMF1WEJ4VGDZ3TQD',
#  'cars:01K3KWCRBPMMA0R2TA2ZNWBBCE',
#  'cars:01K3KWCRBP5MYA1D42JVRCC66W',
#  'cars:01K3KWCRBPM03TWK7MW4DFDSJP',
#  'cars:01K3KWCRBPQFFZRPB45WDN9FT7',
#  'cars:01K3KWCRBPMM1XWH2FZ40TNSP9',
#  'cars:01K3KWCRBPB1KFGW1MV7TQKGSW',
#  'cars:01K3KWCRBPTATVH91488119TGY',
#  'cars:01K3KWCRBPCHKE1GQ8TPXEZP3G',
#  'cars:01K3KWCRBPCWXYVJTMJA81SS4T',
#  'cars:01K3KWCRBP4N0VEQW9DBF9W5T2',
#  'cars:01K3KWCRBPDXJSXXGSKRS45628',
#  'cars:01K3KWCRBPH1KAX58S8QV19V3B',
#  'cars:01K3KWCRBPJCYWK3PR5XP7FPS3',
#  'cars:01K3KWCRBP8NY6GAKM37TGB9B4',
#  'cars:01K3KWCRBPY7JSA5XJVCAWT3BB',
#  'cars:01K3KWCRBPFX7EMZ9QSHYSQNKM',
#  'cars:01K3KWCRBPGZCA3TMV6VT2Q1E3',
#  'cars:01K3KWCRBP0QQWA5RK2EK2622P',
#  'cars:01K3KWCRBPR14BK6VSJTWJXESN',
#  'cars:01K3KWCRBPBABGHSNSSBF1SQ50',
#  'cars:01K3KWCRBPAP065H6AP2F1GQFB',
#  'cars:01K3KWCRBP349Q36FCNM7GKZYT',
#  'cars:01K3KWCRBPTYCMF9ZDTJN3JP7T',
#  'cars:01K3KWCRBPA5X8FMQJN8T5EAP1',
#  'cars:01K3KWCRBPAFFFT2JPDECDKW3Y',
#  'cars:01K3KWCRBP2H9MSRQRKG8MNVHJ',
#  'cars:01K3KWCRBPQP087KZCJ958BY4Q',
#  'cars:01K3KWCRBPJQHZ436NSN0EJE7Q',
#  'cars:01K3KWCRBPXWYB3P4JQA1PGNVS',
#  'cars:01K3KWCRBP26YDWVTPVY3VX40N',
#  'cars:01K3KWCRBPGVCZX8Y66274T074',
#  'cars:01K3KWCRBPC4F7BJ6WWBDRVF28',
#  'cars:01K3KWCRBP8CB076W9HVTTDV0N',
#  'cars:01K3KWCRBPVQWWA55F4S8ZS8D4',
#  'cars:01K3KWCRBPQ5GH2HP2JX4YSC95',
#  'cars:01K3KWCRBPWBEZGG64QS1VS3V9',
#  'cars:01K3KWCRBP5JXRBG9TBP1HNB1R',
#  'cars:01K3KWCRBPD6B4HNP6NFB33YD0',
#  'cars:01K3KWCRBPQMJ2BD49F043GWB3',
#  'cars:01K3KWCRBPC0E3TB8ZWHFY02TC',
#  'cars:01K3KWCRBPEP3FB0ZW61P17YY4',
#  'cars:01K3KWCRBPR0SPDTM8MES43B6E',
#  'cars:01K3KWCRBPMX0G7REV89ED4J8H',
#  'cars:01K3KWCRBPRG3VXQV89BZ0S7ZA',
#  'cars:01K3KWCRBPQCE4E8WF6JREJJ2D',
#  'cars:01K3KWCRBPGEV9743MBB938CQT',
#  'cars:01K3KWCRBPSGRA96HHEDBPHNM4',
#  'cars:01K3KWCRBP9CX970B9JPV26MK2',
#  'cars:01K3KWCRBPFY5VAZW379B86HYN',
#  'cars:01K3KWCRBPJNSVJBAF6XSMS68Y',
#  'cars:01K3KWCRBQE3ZED0RVYK1EP63D',
#  'cars:01K3KWCRBQS3CM9B55STA5187G',
#  'cars:01K3KWCRBQZYFX213WV82K98R1',
#  'cars:01K3KWCRBQ5E0E0NBHEMJNHTDZ',
#  'cars:01K3KWCRBQFBEYMEY5PN4SJ73A',
#  'cars:01K3KWCRBQNYTY3NP2Y56WFNXG',
#  'cars:01K3KWCRBQDW2KTHWHA198GJS7',
#  'cars:01K3KWCRBQ6GTHV7KCCQ0RAV0J',
#  'cars:01K3KWCRBQY60XPDANCC8YDE8R',
#  'cars:01K3KWCRBQ5HG6JZ1VX9CWEKQN',
#  'cars:01K3KWCRBQYZFVDE8EZ82G62DQ',
#  'cars:01K3KWCRBQ7KN5CK13P1FMB1WG',
#  'cars:01K3KWCRBQEJMYXV3F56NRA5ET',
#  'cars:01K3KWCRBQ00EY62Q5SSKB8RV0',
#  'cars:01K3KWCRBQFVX9AC4FSNWVNF2B',
#  'cars:01K3KWCRBQTCC0Y02FN2F91HYQ',
#  'cars:01K3KWCRBQTVV9BC96KNG5X5Z6',
#  'cars:01K3KWCRBQZ2VAMQKK5SJS5S7X',
#  'cars:01K3KWCRBQZTC9H5EQJQ7ZGTR5',
#  'cars:01K3KWCRBQJG3VMRMQGSJHGF71',
#  'cars:01K3KWCRBQYWWMCJE8H1CHPGD7',
#  'cars:01K3KWCRBQHFKGJR4R4SV3JNZ3',
#  'cars:01K3KWCRBQEVWV45J1919JBAY3',
#  'cars:01K3KWCRBQ7EH1VJRAFZVVDWZW',
#  'cars:01K3KWCRBQGB1W5YKWQ051ZZWS',
#  'cars:01K3KWCRBQY7TV4QTW2WS5NR90',
#  'cars:01K3KWCRBQ1M97DHQAW5ASEVET',
#  'cars:01K3KWCRBQKE9JZRMDSXPYFFV9',
#  'cars:01K3KWCRBQJ54AB39ZQ4TSMDMZ',
#  'cars:01K3KWCRBQRKPTBGZSE3DKXX83',
#  'cars:01K3KWCRBQN60255NY03TZMEXQ',
#  'cars:01K3KWCRBQNQZE61NBTZ7Y9YTR',
#  'cars:01K3KWCRBQA1F68QGRNYQZXH8X',
#  'cars:01K3KWCRBQD0Q2G1K2Q64TD1BJ',
#  'cars:01K3KWCRBQKBBB3YC50ZS6VM8Q',
#  'cars:01K3KWCRBQM3QH1992XDT2PJVD',
#  'cars:01K3KWCRBQRRS613GXBXR5KN0B',
#  'cars:01K3KWCRBQKBTEWJMZ98SJXET1',
#  'cars:01K3KWCRBQBNQP15NMD69FWW13',
#  'cars:01K3KWCRBQ1WJ0KZT3TQWMAF59',
#  'cars:01K3KWCRBQ8G83FAYQ43N1KCQ0',
#  'cars:01K3KWCRBQY5Q11FQVRY37509S',
#  'cars:01K3KWCRBQFTAX9GKTVZP1FTQM',
#  'cars:01K3KWCRBQMFFS55KPJ97Q2Y4P',
#  'cars:01K3KWCRBQJ2FQH84VZYXXTJP5',
#  'cars:01K3KWCRBQTGV246XP5PJCD7Q0',
#  'cars:01K3KWCRBQB5X7DTFC3EDMXYZ7',
#  'cars:01K3KWCRBQN3RAVS72YNW53SDP',
#  'cars:01K3KWCRBQY0EX4QJ4VT70RPSX',
#  'cars:01K3KWCRBQHF9PKSMEQKZDRAXW',
#  'cars:01K3KWCRBQYB1HXBV13MXBCWJT',
#  'cars:01K3KWCRBQ9CDT12KNQMQN5ZEW',
#  'cars:01K3KWCRBQYYTTAAGTEC5FHF7H',
#  'cars:01K3KWCRBQTYGHE6VAZF2398R9',
#  'cars:01K3KWCRBQZ9C51EJZWWB2KKCF',
#  'cars:01K3KWCRBQCEAN911XYJ5RBNRW',
#  'cars:01K3KWCRBQGCRXC1F7SD2BKVFF',
#  'cars:01K3KWCRBQHQ3TSR0YH9Z41MK0',
#  'cars:01K3KWCRBQDQ29302KRAKZ5A7G',
#  'cars:01K3KWCRBQ88J1W9MFDXEYRDX8',
#  'cars:01K3KWCRBQDPDADP0YHKHB25HZ',
#  'cars:01K3KWCRBQ6ZDW5QT6DVQAJGNA',
#  'cars:01K3KWCRBQPKVSFXDESYY0FXXT',
#  'cars:01K3KWCRBQ7QFJ0907HGGJ9DAD',
#  'cars:01K3KWCRBQE4A30RKQCMEM84D7',
#  'cars:01K3KWCRBQEM8KEGS1JZN4B3FA',
#  'cars:01K3KWCRBQ8E9PYYQFYGKMBRCS',
#  'cars:01K3KWCRBQE66AM4NZQERTYMXM',
#  'cars:01K3KWCRBQDMCY1PGG2T52GAXG',
#  'cars:01K3KWCRBQEPW0EXBNHBS7YW0P',
#  'cars:01K3KWCRBQA2JMZVZYF84C3254',
#  'cars:01K3KWCRBQ69G6NM4SDCM32KN6',
#  'cars:01K3KWCRBQXYZ6EM9EH4JDMR72',
#  'cars:01K3KWCRBQ5DSFXJS2F295YQ4J',
#  'cars:01K3KWCRBQ3H8MX3B0P04XD7AB',
#  'cars:01K3KWCRBQS0K1MD6YP57VKHH4',
#  'cars:01K3KWCRBQ0AKTF609YA7V5K65',
#  'cars:01K3KWCRBQXKKAAP230JKJXG1J',
#  'cars:01K3KWCRBQQFF7B6RFWDFEAF8R',
#  'cars:01K3KWCRBQY21CCWZVC190YQN6',
#  'cars:01K3KWCRBQ52GZVTZ56K3KAGAT',
#  'cars:01K3KWCRBQVRZB5JZZ19X78N6G',
#  'cars:01K3KWCRBQB600JVQHGYZYZHBF',
#  'cars:01K3KWCRBQA6T5MSX9ZRDYKGZY',
#  'cars:01K3KWCRBQZWF2ENR6TESKDE53',
#  'cars:01K3KWCRBQ7RP2VTQPWHTHEFFX',
#  'cars:01K3KWCRBQXN1NMFDEDSCC0751',
#  'cars:01K3KWCRBQ05PZGMFYNTB63A49',
#  'cars:01K3KWCRBQS6ZX3W06D6ZVZ08E',
#  'cars:01K3KWCRBQ8GGQNEVQYQWW6952',
#  'cars:01K3KWCRBQJ5RHR50PB1083DX3',
#  'cars:01K3KWCRBQM97D1GN5A3QBHE2Y',
#  'cars:01K3KWCRBQCTHGFQCSM202JR1B',
#  'cars:01K3KWCRBQX3STBG45FHMYQF5N',
#  'cars:01K3KWCRBQVC703VTC62E2C089',
#  'cars:01K3KWCRBQXDBS9AKVQXWX045M',
#  'cars:01K3KWCRBQGHA1W105GA3BTGHT',
#  'cars:01K3KWCRBQDKHZA99VBJ33ZZC3',
#  'cars:01K3KWCRBQWXAS9H7J88P7ESAK',
#  'cars:01K3KWCRBQ8DHZPFJ2J6X1H218',
#  'cars:01K3KWCRBQT9M3KFFWDDXR27K9',
#  'cars:01K3KWCRBQ4PJAK108TZSV81Q3',
#  'cars:01K3KWCRBQY7WR00RQ8CTS4TMY',
#  'cars:01K3KWCRBQVQ076V150N0G9AYZ',
#  'cars:01K3KWCRBQEHT0SGNN6A6PYAAQ',
#  'cars:01K3KWCRBQ0AN8PHFRXCSQNVCR',
#  'cars:01K3KWCRBQ1YBH2KBNX0QA5JTM',
#  'cars:01K3KWCRBQ0F3J0NZGGJYEYSD9',
#  'cars:01K3KWCRBQT84RKHDXVEWK9GBB',
#  'cars:01K3KWCRBQ8JP3H7QMW10TZZ70',
#  'cars:01K3KWCRBQK65PH6YHRACWGFZ3',
#  'cars:01K3KWCRBQD949SF2TW5SAFTY7',
#  'cars:01K3KWCRBQTCXH0KJWWJRS0059',
#  'cars:01K3KWCRBQNGRPXWZTKF38VEFK',
#  'cars:01K3KWCRBQ8SRWFYS3J2G1EKCE',
#  'cars:01K3KWCRBQ5E1NPHXFMK90QMDN',
#  'cars:01K3KWCRBQPZAV2MSKVFQ47756',
#  'cars:01K3KWCRBQAM43PNYRC41A5M3H',
#  'cars:01K3KWCRBQRGRSDQKY609M0C2T',
#  'cars:01K3KWCRBQ416NZ42RRHA4QZSM',
#  'cars:01K3KWCRBQB8Z5NEBXY3XTXPQN',
#  'cars:01K3KWCRBQP6BXG50WQ9R450T7',
#  'cars:01K3KWCRBQ6TBSNGVEM2P1X8XA',
#  'cars:01K3KWCRBQ9XZ8QXHH1BQHEA76',
#  'cars:01K3KWCRBQ04SF8RA1RVC3DS5P',
#  'cars:01K3KWCRBQA6WXPFP3BZF1T5KH',
#  'cars:01K3KWCRBQ5VDSARW382H83BCH',
#  'cars:01K3KWCRBQG5JBKRDMFZK25X8P',
#  'cars:01K3KWCRBQ35MJ0GM3BTR9EAT7',
#  'cars:01K3KWCRBQRRE5N2JRAQGF3R3Z',
#  'cars:01K3KWCRBQ2HTVV1T2ZF34FAT6',
#  'cars:01K3KWCRBQ203GG5D80C4P22R1',
#  'cars:01K3KWCRBQ9N62GQ674HE4D07E',
#  'cars:01K3KWCRBQD1S31DN324Q5SGZQ',
#  'cars:01K3KWCRBQBG6ZE5C3R2X1VFGN',
#  'cars:01K3KWCRBQ12XRK8VKSF20BRW9',
#  'cars:01K3KWCRBQHQNBQEW3PAER4W1B',
#  'cars:01K3KWCRBQ8ZKF1TQPB2EB5SRN',
#  'cars:01K3KWCRBQNA43AZDGQTAD530C',
#  'cars:01K3KWCRBQ3QXNR1Y4Y42H9EA4',
#  'cars:01K3KWCRBQWYG5W5E896G7NG50',
#  'cars:01K3KWCRBQ108XAZXESEY0YS42',
#  'cars:01K3KWCRBQW1SHEJ89ETJTHQK5',
#  'cars:01K3KWCRBQVBX1F20K14S2AEP0',
#  'cars:01K3KWCRBQBKWZV0ZMAAA385ZB',
#  'cars:01K3KWCRBQV2V6CFE34VZY4Y5R',
#  'cars:01K3KWCRBQ3FGR8QPXX7GFD7RB',
#  'cars:01K3KWCRBQ4EY9MPXZWV4TE6QA',
#  'cars:01K3KWCRBQYD0PE5YDFC5BC5WJ',
#  'cars:01K3KWCRBQ79KZ7HX9QRT3P381',
#  'cars:01K3KWCRBQ5M9RZ624D7QB400V',
#  'cars:01K3KWCRBQQQQJGCJQC218VR7N',
#  'cars:01K3KWCRBQXDN92WDW819QY2AB',
#  'cars:01K3KWCRBQ0DYJ6ZVDEVBXPS5P',
#  'cars:01K3KWCRBQMTJQA224C8M1KHRH',
#  'cars:01K3KWCRBQB513YFSXCWZ7QP2K',
#  'cars:01K3KWCRBQEY9G3PMY8Z3VWKD2',
#  'cars:01K3KWCRBQ3XZAKD41Q6SAXTWQ',
#  'cars:01K3KWCRBQHM0V8VGCBXAXC9Z0',
#  'cars:01K3KWCRBQ606WHABJC3A2JK12',
#  'cars:01K3KWCRBQQ5BW0803ZCTG9S31',
#  'cars:01K3KWCRBQM3KZDSF6WV2KKWT9',
#  'cars:01K3KWCRBQAYEWCDWMXNXETKK4',
#  'cars:01K3KWCRBQ4720C0HV6PVT0FW5',
#  'cars:01K3KWCRBQFXWFEVBFTZRP22NM',
#  'cars:01K3KWCRBQQ8HS95NQ07XX4JCX',
#  'cars:01K3KWCRBQRVJX9JS3VHHYZV92',
#  'cars:01K3KWCRBQTXH3X355QH0R0JZD',
#  'cars:01K3KWCRBQ26FNY3BD4J5HQ5HZ',
#  'cars:01K3KWCRBQRHWQAGK35WNRB9YX',
#  'cars:01K3KWCRBQ6AHZYBAAWETK9FJF',
#  'cars:01K3KWCRBQC48G32BNQRPGPJQJ',
#  'cars:01K3KWCRBQVPYG6E7CK7EJNTFJ',
#  'cars:01K3KWCRBQHEED3X0HF1R78WW9',
#  'cars:01K3KWCRBQVBSEHP1ENEA3WQJR',
#  'cars:01K3KWCRBQC7YTEVGVRJGHFX57',
#  'cars:01K3KWCRBQJEZSV58SKT65K2SK',
#  'cars:01K3KWCRBQFD0Z3W0TK5J42KFM',
#  'cars:01K3KWCRBQTAEE50S518E96RM2',
#  'cars:01K3KWCRBQAZA2MS6SNPS971F5',
#  'cars:01K3KWCRBQAEP008CT6GBZJMZC',
#  'cars:01K3KWCRBQ3AMT583H2QYKS868',
#  'cars:01K3KWCRBQDG88ZQYMCVV88AKC',
#  'cars:01K3KWCRBQQNDS8QV09KNNMSMB',
#  'cars:01K3KWCRBQWCE685CX5QKY2WDA',
#  'cars:01K3KWCRBQAY7GFH27DJHQ6DHP',
#  'cars:01K3KWCRBQVA7Q2R84XWEKNWP1',
#  'cars:01K3KWCRBQ0SVWQ5BFRDP6FF8J',
#  'cars:01K3KWCRBQ2QZ2WNNGBG5XCY6V',
#  'cars:01K3KWCRBQZ6E35N7YJYBFR77N',
#  'cars:01K3KWCRBQD53PYZENQGZ3C7WR',
#  'cars:01K3KWCRBQHCTZR0JC1HFJET5N',
#  'cars:01K3KWCRBQ6R2FPRGFTJSFAVPE',
#  'cars:01K3KWCRBQF2XBCZ8F9Q2FJ8PD',
#  'cars:01K3KWCRBQHCGRMKDSHZRNQBWK',
#  'cars:01K3KWCRBQ1HX2DCSN8BD33WM6',
#  'cars:01K3KWCRBQD3C4HK674B47HPG6',
#  'cars:01K3KWCRBQF4188SVE1DKB5TST',
#  'cars:01K3KWCRBQ79F8BWJN961Z73A2',
#  'cars:01K3KWCRBQWEFSN4YA946K1JHM',
#  'cars:01K3KWCRBQBEG2YW2HZ8CR5H9D',
#  'cars:01K3KWCRBQE2E2CJN1R04SNX5G',
#  'cars:01K3KWCRBQRAVP5AHG1HCJD7Z4',
#  'cars:01K3KWCRBQP55MGKG0JFRMB2SM',
#  'cars:01K3KWCRBQ9N99QWG6TWVFSZT4',
#  'cars:01K3KWCRBQM1A2FFP0VYE72GAN',
#  'cars:01K3KWCRBQ02590Q2AX52DN67A',
#  'cars:01K3KWCRBQ81V7TQRF9E7NS8VG',
#  'cars:01K3KWCRBQ6JWW2XH647D5G63R',
#  'cars:01K3KWCRBQ271NEVK9BSDKV0RR',
#  'cars:01K3KWCRBQFR02CC1DXMPQEFBK',
#  'cars:01K3KWCRBQWZVDJ49K7B5X8N16',
#  'cars:01K3KWCRBQMB2G8YQAW6DGMVDE',
#  'cars:01K3KWCRBQBHDSX02GD69B0SQ8',
#  'cars:01K3KWCRBQTWAQ8SQZGZ45Y5CV',
#  'cars:01K3KWCRBQPSMPC4A512174TK4',
#  'cars:01K3KWCRBQDGSK7Q8CMEFG699D',
#  'cars:01K3KWCRBQM27TR3PGWCE88Z84',
#  'cars:01K3KWCRBQ37JSQNKQTWCKZ1NE',
#  'cars:01K3KWCRBQ55R6TJZZ66XXMQYS',
#  'cars:01K3KWCRBQA4HGXGCGH9KNTFR2',
#  'cars:01K3KWCRBQXW3SGJBKKMBX6QRN',
#  'cars:01K3KWCRBQT5B1MJVXSG3R0WG7',
#  'cars:01K3KWCRBQRTTPPEYA21AGCZRS',
#  'cars:01K3KWCRBQWERXES719623GK2V',
#  'cars:01K3KWCRBQ88XW867NJ2ZNHY77',
#  'cars:01K3KWCRBQ4QKNDYG2WNXQZCSC',
#  'cars:01K3KWCRBQ3Z0BCCSJ0KE18EJ9',
#  'cars:01K3KWCRBQFA21STAKTA1GCQ0F',
#  'cars:01K3KWCRBQHMB0H8669J8MC8RQ',
#  'cars:01K3KWCRBQTKTMJ000YVPBM3TX',
#  'cars:01K3KWCRBQD0Q5PJGZZSW5TV5T',
#  'cars:01K3KWCRBQFPM2F7J9Q7TPAB88',
#  'cars:01K3KWCRBRJY8VJYMBM5PVA252',
#  'cars:01K3KWCRBR370WZ0KHKHQ4N86E',
#  'cars:01K3KWCRBR1387TZGNKN73HK96',
#  'cars:01K3KWCRBRWJ5R796SZWEXRSTW',
#  'cars:01K3KWCRBR9RKZN2VDKQKPJ3D4',
#  'cars:01K3KWCRBRWWR5HZ1W3S18ZR0J',
#  'cars:01K3KWCRBRBA5YDANKNM3MA0NZ',
#  'cars:01K3KWCRBRJBK1SNB3425D694W',
#  'cars:01K3KWCRBRWD2D50WPJ530DB2V',
#  'cars:01K3KWCRBR27JGFK7A3SZR5J00',
#  'cars:01K3KWCRBRPRK4PJ5TTE4GXWKE',
#  'cars:01K3KWCRBRE0SMQS8QYVZK5KVB',
#  'cars:01K3KWCRBR0DM5S9PZ6KNGWB5S',
#  'cars:01K3KWCRBRY730K5KFMSA3NSC9',
#  'cars:01K3KWCRBRPZSRDGHK832R910X',
#  'cars:01K3KWCRBRBDN1ZXGYW7C5NCZK',
#  'cars:01K3KWCRBR3Y3VH9SDKQDQG0NM',
#  'cars:01K3KWCRBR7BY1WSCVX0ZHYR3S',
#  'cars:01K3KWCRBR5CMW9SGX8YT8880V',
#  'cars:01K3KWCRBRMNSWSKZ6TXJYWQ9M',
#  'cars:01K3KWCRBR0E36HVSG7DTBZPXC',
#  'cars:01K3KWCRBR2ZD07P3CHXP60HR1',
#  'cars:01K3KWCRBR240CK2RV683SG8DA',
#  'cars:01K3KWCRBR0AMYN04GSGW5KFZT',
#  'cars:01K3KWCRBRQNMSTERGXW2XDTDB',
#  'cars:01K3KWCRBRBDK2A83E0W443XNK',
#  'cars:01K3KWCRBR2NT2S7JM5NNE4QM4',
#  'cars:01K3KWCRBR2MC2V0Z8BCZQD4BX',
#  'cars:01K3KWCRBR3VKHGF09FR5MP6ZG',
#  'cars:01K3KWCRBRKW79JW8QWKHGBAZQ',
#  'cars:01K3KWCRBRS2373513CBDBE2MP',
#  'cars:01K3KWCRBR9YKK65YCR4FBVCHY',
#  'cars:01K3KWCRBRRG5EVTA0BXK37W9M',
#  'cars:01K3KWCRBRCTZ4P3YM24EVFST9',
#  'cars:01K3KWCRBRVGX9E3MCGKFEC3PD']

# %% [markdown]
# # Check index created successfully

# %%
index.info()["num_docs"]
# Out:
# 464

# %% [markdown]
# # Review search study config
#
# - index_name should point to index created above
# - qrels and queries should point to the queries and set of labeled queries under test
# - search methods should match with the custom methods defined below
# - embedding_model should match with the one used to create the index

# %%
from redis_retrieval_optimizer.utils import load_search_study_config

search_study_config = load_search_study_config("search_study_config.yaml")
search_study_config
# Out:
# SearchStudyConfig(study_id='test-search-study', index_name='cars', qrels='../resources/cars/car_qrels.json', queries='../resources/cars/car_queries.json', search_methods=['base_vector', 'pre_filter_vector'], ret_k=3, id_field_name='_id', vector_field_name='vector', text_field_name='text', embedding_model=EmbeddingModel(type='hf', model='sentence-transformers/all-mpnet-base-v2', dim=768, embedding_cache_name='vec-cache', dtype='float32'))

# %% [markdown]
# # Define search methods for search study
#
# A search method can be anything as long as it takes a `SearchMethodInput` and returns a `SearchMethodOutput`. Below we will compare a basic vector search to a vector search with a pre-filter.

# %%
from ranx import Run
from redis_retrieval_optimizer.search_methods.base import run_search_w_time
from redisvl.query import VectorQuery
from redisvl.query.filter import Tag

from redis_retrieval_optimizer.schema import SearchMethodInput, SearchMethodOutput
from redis_retrieval_optimizer.search_methods.vector import make_score_dict_vec

def vector_query(query_info, num_results: int, emb_model) -> VectorQuery:
    vector = emb_model.embed(query_info["query"], as_buffer=True)

    return VectorQuery(
        vector=vector,
        vector_field_name="vector",
        num_results=num_results,
        return_fields=["item_id", "make", "model", "text"],  # update to read from env maybe?
    )

def pre_filter_query(query_info, num_results, emb_model) -> VectorQuery:
    vec = emb_model.embed(query_info["query"])
    make = query_info["query_metadata"]["make"]
    model = query_info["query_metadata"]["model"]

    filter = (Tag("make") == make) & (Tag("model") == model)

    # Create a vector query
    query = VectorQuery(
        vector=vec,
        vector_field_name="vector",
        num_results=num_results,
        filter_expression=filter,
        return_fields=["item_id", "make", "model", "text"]
    )

    return query

def gather_pre_filter_results(search_method_input: SearchMethodInput) -> SearchMethodOutput:
    redis_res_vector = {}

    for key, query_info in search_method_input.raw_queries.items():
        # Format query to run
        query = pre_filter_query(query_info, search_method_input.ret_k, search_method_input.emb_model)
        
        # Run with search time
        res = run_search_w_time(
            search_method_input.index, query, search_method_input.query_metrics
        )

        # Generate search dict
        score_dict = make_score_dict_vec(res, id_field_name="item_id")

        redis_res_vector[key] = score_dict

    return SearchMethodOutput(
        run=Run(redis_res_vector),
        query_metrics=search_method_input.query_metrics,
    )


def gather_vector_results(search_method_input: SearchMethodInput) -> SearchMethodOutput:
    redis_res_vector = {}

    for key, query_info in search_method_input.raw_queries.items():
        vec_query = vector_query(query_info, search_method_input.ret_k, search_method_input.emb_model)
        
        res = run_search_w_time(
            search_method_input.index, vec_query, search_method_input.query_metrics
        )
        
        score_dict = make_score_dict_vec(res, id_field_name="item_id")
        redis_res_vector[key] = score_dict
        
    return SearchMethodOutput(
        run=Run(redis_res_vector),
        query_metrics=search_method_input.query_metrics,
    )

# %% [markdown]
# # Run the search study

# %%
from redis_retrieval_optimizer.search_study import run_search_study

# Note: must match with what's in the search_study_config.
SEARCH_METHOD_MAP = {
    "base_vector": gather_vector_results,
    "pre_filter_vector": gather_pre_filter_results
}

metrics = run_search_study(
    config_path="search_study_config.yaml",
    redis_url=redis_url,
    search_method_map=SEARCH_METHOD_MAP
)
# Out:
# Connecting to existing index: cars
# Connected to index: cars with 464 objects
# 15:06:36 sentence_transformers.SentenceTransformer INFO   Use pytorch device_name: mps
# 15:06:36 sentence_transformers.SentenceTransformer INFO   Load pretrained SentenceTransformer: sentence-transformers/all-mpnet-base-v2
# Running search method: base_vector
# Running search method: pre_filter_vector

# %%
metrics
# Out:
#        search_method total_indexing_time  total_memory_mb  avg_query_time  \
# 0        base_vector  119.24700164794922        17.250219        0.001397
# 1  pre_filter_vector  119.24700164794922        17.250219        0.000441
#
#      recall      ndcg        f1  precision  ret_k
# 0  0.675000  0.668037  0.519683   0.466667      3
# 1  0.741667  0.794658  0.581905   0.533333      3
