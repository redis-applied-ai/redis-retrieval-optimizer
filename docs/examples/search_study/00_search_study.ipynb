# %% [markdown]
# # Search study
#
# Let's say you have an existing Redis database with a search index seeded. You may wish to quickly test different search method against the existing index without having to recreate data and/or recreate the index. This demo will walk you though how to set this up and get going.
#
# # Installation

# %%
# %pip install redis-retrieval-optimizer

# %% [markdown]
# # Load data
#
# We will load our custom car dataset for this example.

# %%
import json

with open('../resources/cars/car_corpus.json', 'r') as f:
    corpus = json.load(f)

with open('../resources/cars/car_queries.json', 'r') as f:
    queries = json.load(f)

with open('../resources/cars/car_qrels.json', 'r') as f:
    qrels = json.load(f)

# %% [markdown]
# # Create the index with redisvl
#
# For the search_study we are assuming that the search index already exists. The cell below will create a Redis search index and populate it with our test data for example purposes but is assumed with a search study is populated and running within your data.
#
# Note: the demo assumes you have a instance of redis running on localhost:6379. If this is not the case, update the redis_url to direct to your running instance or start a local instance with the following command.
#
# `docker run -d --name redis-stack-server -p 6379:6379 redis/redis-stack-server:latest`

# %%
# assuming you have a redis instance running on localhost:6379
redis_url = "redis://localhost:6379"

# %%
from redisvl.index import SearchIndex
from redisvl.utils.vectorize import HFTextVectorizer

emb_model = HFTextVectorizer()

# define schema
car_schema = {
    "index": {
        "name": "cars",
        "prefix": "cars"
    },
    "fields": [
        {"name": "item_id", "type": "tag"},
        {"name": "text", "type": "text"},
        {"name": "make", "type": "tag"},
        {"name": "model", "type": "tag"},
        {
            "name": "vector",
            "type": "vector",
            "attrs": {
                "dims": 768,
                "distance_metric": "cosine",
                "algorithm": "FLAT",
                "datatype": "float32"
            },
        },
    ]
}

# create index
index = SearchIndex.from_dict(car_schema, redis_url=redis_url)
index.create(overwrite=True)

embeddings = emb_model.embed_many([c["text"] for c in corpus], as_buffer=True)

# vectorize corpus data
corpus_data = [
    {
        "text": c["text"],
        "item_id": c["item_id"],
        "make": c["query_metadata"]["make"],
        "model": c["query_metadata"]["model"],
        "vector": embeddings[i]
    }
    for i, c in enumerate(corpus)
]

index.load(corpus_data)
# Out:
# 10:54:37 sentence_transformers.SentenceTransformer INFO   Use pytorch device_name: mps
# 10:54:37 sentence_transformers.SentenceTransformer INFO   Load pretrained SentenceTransformer: sentence-transformers/all-mpnet-base-v2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ['cars:01K1TS7X60PECFRE25YJSR7DPE',
#  'cars:01K1TS7X60YX173ZP1CZDK6CJ8',
#  'cars:01K1TS7X60QMR91EWNKVYNJHD9',
#  'cars:01K1TS7X60PX94HVJ6424948Y5',
#  'cars:01K1TS7X60PTVVW50NW7RM0FDJ',
#  'cars:01K1TS7X60Y84456F020SSYD9W',
#  'cars:01K1TS7X605FHP6S8SWMBECHWP',
#  'cars:01K1TS7X60FTN8KHC0BE7VQZKK',
#  'cars:01K1TS7X60VED47KCJ9DVX0R63',
#  'cars:01K1TS7X60FTB15MYVESHZ1GM2',
#  'cars:01K1TS7X603HY3HXQ5F4HCEGFF',
#  'cars:01K1TS7X60J8J069REJTREGS9M',
#  'cars:01K1TS7X60XANC89D80NA3TPSE',
#  'cars:01K1TS7X60KHZV7TDA5H0N5168',
#  'cars:01K1TS7X60AC5WNSKXMHKXPSKW',
#  'cars:01K1TS7X60MXS5W45CGX36330D',
#  'cars:01K1TS7X60ZCMKJ4X7T9PR5146',
#  'cars:01K1TS7X61JP8TFKCCSFFZX0NN',
#  'cars:01K1TS7X61MXZ130ZST71RFVNJ',
#  'cars:01K1TS7X61FM9ZH6AN5YED2GTN',
#  'cars:01K1TS7X61B81J41HX30SMRSW1',
#  'cars:01K1TS7X61B0W51BA72KZDHK0N',
#  'cars:01K1TS7X61QVX4CJ3B652Z4H6F',
#  'cars:01K1TS7X61WFDM46F5DW6D69G7',
#  'cars:01K1TS7X61VMMS75HN70VY94F7',
#  'cars:01K1TS7X61AEFHB3V3WHY8VX01',
#  'cars:01K1TS7X6125PHDTWXX6TMXZ3Z',
#  'cars:01K1TS7X612BK842KEHC756RND',
#  'cars:01K1TS7X61YBBYS2AYFEZAE9V5',
#  'cars:01K1TS7X61F4DA70C0MESDKGKA',
#  'cars:01K1TS7X61KHE7VZ67D1SR0T0N',
#  'cars:01K1TS7X6142H1SKXB2S8QPG3G',
#  'cars:01K1TS7X61MNNGFA19GM4N8XYB',
#  'cars:01K1TS7X61P6BZPM0DSECCCEPF',
#  'cars:01K1TS7X61FA4Y3YWMR082A35C',
#  'cars:01K1TS7X61BXMWSFJVN6542PXS',
#  'cars:01K1TS7X61SFWPK049RX3NTRD0',
#  'cars:01K1TS7X61THMC727Q08T6DR5Y',
#  'cars:01K1TS7X61FK8GZ581VQ7483MZ',
#  'cars:01K1TS7X619QPCA0M6FNJWF5E7',
#  'cars:01K1TS7X61MM39SV4KDBMWBF4Y',
#  'cars:01K1TS7X61QXE51C1ETN4A0PM2',
#  'cars:01K1TS7X61M4E2171JV0JHDB0R',
#  'cars:01K1TS7X61M85CYP8J1C5ERJSQ',
#  'cars:01K1TS7X616B6MW2AM73B6HB8D',
#  'cars:01K1TS7X613YGJRVMDDT51CBXE',
#  'cars:01K1TS7X613FW2PCTXXWZF394W',
#  'cars:01K1TS7X61APTY9YQDVT05RNGG',
#  'cars:01K1TS7X61CX7KP0NHD9R1JW01',
#  'cars:01K1TS7X61MYD4CWGYJ8HP5DWP',
#  'cars:01K1TS7X61V807G1KX385F2PGD',
#  'cars:01K1TS7X61W3FVTX6PQN8GMQCB',
#  'cars:01K1TS7X61S69WQCYTJJKK9JMP',
#  'cars:01K1TS7X61B0D3HQ01BGT3QAWX',
#  'cars:01K1TS7X614A2DMWGZGKHRX9D7',
#  'cars:01K1TS7X615CJ36TYX0W3XPYT1',
#  'cars:01K1TS7X61Y2QFDZC057M5HAZZ',
#  'cars:01K1TS7X61B0PVG2SA52CATK2F',
#  'cars:01K1TS7X61X4CT5X146XCBKC7Q',
#  'cars:01K1TS7X61RPBXSV4FPRN00K7A',
#  'cars:01K1TS7X61BY6RGBBN7D0RXT04',
#  'cars:01K1TS7X615HN8SEP2M0C4HAK5',
#  'cars:01K1TS7X61VAXMAMRZ7JPW7673',
#  'cars:01K1TS7X61M68DTKRC63VXJB2C',
#  'cars:01K1TS7X613W218HG6JH8PVBR8',
#  'cars:01K1TS7X619TE6GDAR66510N74',
#  'cars:01K1TS7X61SCNXCZVSECKNB7RP',
#  'cars:01K1TS7X61FCG7BQ4PA0FWVHB7',
#  'cars:01K1TS7X61ME9K8BJNGEQ1T9PB',
#  'cars:01K1TS7X61ZRYZQAJWCPJPWWET',
#  'cars:01K1TS7X61BKNTB9QB10R0R1TJ',
#  'cars:01K1TS7X61WHQ5DYYDRMYXAWT1',
#  'cars:01K1TS7X61E26EYPDEJPNDXTQK',
#  'cars:01K1TS7X61K47PV1BSVMWT6958',
#  'cars:01K1TS7X61T7DZHYZ4HTD0FASJ',
#  'cars:01K1TS7X610642N7KREXPVCM8P',
#  'cars:01K1TS7X613C8JFY6XGRTX594F',
#  'cars:01K1TS7X61XBP49CM832SQB06M',
#  'cars:01K1TS7X61PNWEN63YN1N5XF0T',
#  'cars:01K1TS7X611GM8HBKRNWWWVRFQ',
#  'cars:01K1TS7X61FW3QTCJNH3TEVTEH',
#  'cars:01K1TS7X61CVQ73A480R33GDS1',
#  'cars:01K1TS7X61A5B5N27WDCJEX4H9',
#  'cars:01K1TS7X61QWYZ25DGKVGCAM7C',
#  'cars:01K1TS7X615RHJ0VDGP7JYETPD',
#  'cars:01K1TS7X613MQRTRZRR2JH54A0',
#  'cars:01K1TS7X61P1QMC0V3KTARXSSM',
#  'cars:01K1TS7X61MDCAZY8Y7QN2WW1A',
#  'cars:01K1TS7X61T6XJ9TMGS46V6MAJ',
#  'cars:01K1TS7X61WNKY3HWTAT3K7C86',
#  'cars:01K1TS7X61DDMKF4SE9MNWW8FR',
#  'cars:01K1TS7X61ZB00JTABSSF5WPZW',
#  'cars:01K1TS7X61TCP0HSNEVB229R51',
#  'cars:01K1TS7X61JYA2R5CE81DPBG7Y',
#  'cars:01K1TS7X6161D1Q0C01995ZQRQ',
#  'cars:01K1TS7X61K9CCYWTMH9KV4BVC',
#  'cars:01K1TS7X61KAYSREKVDNN189ZA',
#  'cars:01K1TS7X61SMFZSRYNED55K639',
#  'cars:01K1TS7X615A6MMVTFAMQFVREG',
#  'cars:01K1TS7X61PJ3NRVV0M6XDW1ZP',
#  'cars:01K1TS7X61ZYQAJNY4YPKA6RV8',
#  'cars:01K1TS7X61K9KVRH0CKANN9FR8',
#  'cars:01K1TS7X61GM9XT3Y6ETVC491B',
#  'cars:01K1TS7X61C36X5BAA00K0K8J2',
#  'cars:01K1TS7X61TBSSGGGEXT1NBJJN',
#  'cars:01K1TS7X61RSTM4H23WZ8H2DZ5',
#  'cars:01K1TS7X6111578DXCMMYYMJ52',
#  'cars:01K1TS7X61YET18KTS03HJGY2X',
#  'cars:01K1TS7X61G5KY4C4ASD8VA976',
#  'cars:01K1TS7X61YZ04YQRGTF0DQX53',
#  'cars:01K1TS7X61V5RRJY1Q5ZMGT68W',
#  'cars:01K1TS7X61HJEWFB1QNFH72A9F',
#  'cars:01K1TS7X617RZS362XKN49K5BP',
#  'cars:01K1TS7X61X15WF97WV9GCTM5K',
#  'cars:01K1TS7X61TEM2C1TEWQV9ZKYG',
#  'cars:01K1TS7X61WBC43J9W1BSWR4VF',
#  'cars:01K1TS7X614ZG8GYNVC29CW47Y',
#  'cars:01K1TS7X61PHQTD989EPENTJWT',
#  'cars:01K1TS7X616MXD2DR0644MY748',
#  'cars:01K1TS7X614EBW9MCXTBF93MHF',
#  'cars:01K1TS7X612GBZH6DW4CR0XH0K',
#  'cars:01K1TS7X61NQ2NM3JEZ16SV0PD',
#  'cars:01K1TS7X61N33CVJTC4T0QK6B1',
#  'cars:01K1TS7X61SA5TRX8SV7F3SYGZ',
#  'cars:01K1TS7X61AA57F4FKRP39FPCS',
#  'cars:01K1TS7X6106TC5GZ7WX2BCT4K',
#  'cars:01K1TS7X61A9P2D27EPKPMXEYK',
#  'cars:01K1TS7X61V1ZDV4N4HCEB3BDN',
#  'cars:01K1TS7X616ZCRJ7GWG3VQ936K',
#  'cars:01K1TS7X61DYFQZ26CJSP2NEKM',
#  'cars:01K1TS7X61C5YBYE2R6BA5QR8W',
#  'cars:01K1TS7X61BJ8HY4XFGCKNHSMH',
#  'cars:01K1TS7X61GYKV5WQP0Y4RSWZ7',
#  'cars:01K1TS7X62WX42D52EANN2YBQ6',
#  'cars:01K1TS7X620C9KMD481NV2K11P',
#  'cars:01K1TS7X62HEPEERWK8WGFE7HP',
#  'cars:01K1TS7X62R4TKD3AJ2C0YMFQW',
#  'cars:01K1TS7X622ZAMWHW3EB2ARECE',
#  'cars:01K1TS7X62X55SXKSWERWEA668',
#  'cars:01K1TS7X621W482N4E6KRYNY74',
#  'cars:01K1TS7X62FEG2JVAY2KDDCW3H',
#  'cars:01K1TS7X6218RNYFJZCM6KXZE6',
#  'cars:01K1TS7X620MN25DJJ45VV5MZP',
#  'cars:01K1TS7X62JJF7ZCVJEHB82P55',
#  'cars:01K1TS7X621MBK69NVRFPFZ15A',
#  'cars:01K1TS7X62CG2ET757H5B75J04',
#  'cars:01K1TS7X62K4NC9F61TJF39KA0',
#  'cars:01K1TS7X62BV0D27BRTS2E6JYY',
#  'cars:01K1TS7X624B6BVRP9FVPNFDGW',
#  'cars:01K1TS7X62KD1MBH1YRCN0XW4Q',
#  'cars:01K1TS7X62296CFESBA82BXHFC',
#  'cars:01K1TS7X62P086ES7CJ5GSZJC5',
#  'cars:01K1TS7X62GXJ72ZCHVKT066SK',
#  'cars:01K1TS7X62AE1KTYZWN18EPTBT',
#  'cars:01K1TS7X624BMSFS7PQEHREEXD',
#  'cars:01K1TS7X62Q9KNNTJR6Z0CW99N',
#  'cars:01K1TS7X62Q9BE8G9FF1D3AGXB',
#  'cars:01K1TS7X62XJNGSDWXQJQFTWBX',
#  'cars:01K1TS7X62XEHYVE8DZRPSBFBN',
#  'cars:01K1TS7X62MX9TVVMQ7QAFSE3H',
#  'cars:01K1TS7X62ETWHRJKNJY54Q2EF',
#  'cars:01K1TS7X62CPXPWXVB0VCGSQW6',
#  'cars:01K1TS7X62KHQW67S3VZ403FB0',
#  'cars:01K1TS7X62SVQJ68Q6ZM8MQX0G',
#  'cars:01K1TS7X623FS8F10C4B9J9ZPN',
#  'cars:01K1TS7X62500N0R1C15QAHBB9',
#  'cars:01K1TS7X6239MF4QV2FTZP936K',
#  'cars:01K1TS7X62W22DKB5NG12YCKRM',
#  'cars:01K1TS7X624FYA33CCYAPWF0RY',
#  'cars:01K1TS7X62WYTAVXW69D41J6E1',
#  'cars:01K1TS7X625VHVDD89W7XARNPG',
#  'cars:01K1TS7X624F2MQGA1YSSAJZPW',
#  'cars:01K1TS7X62FMBECF5A96CAKBSA',
#  'cars:01K1TS7X62J8ABMD06NRH341MA',
#  'cars:01K1TS7X62SWCCSPZQR904Z757',
#  'cars:01K1TS7X62SAXA0Z3EXBRJA3FK',
#  'cars:01K1TS7X62YP6YBZ4QEW04WKWN',
#  'cars:01K1TS7X625GAN0PCJHGQNPVR8',
#  'cars:01K1TS7X62KQ48TEZERWH9XPRB',
#  'cars:01K1TS7X62KF622MGDCYYMM6PM',
#  'cars:01K1TS7X62VACQGMTSQDER19JY',
#  'cars:01K1TS7X62J4Q8D5VJ726KMPTB',
#  'cars:01K1TS7X622DCS1P03DSV5KTPY',
#  'cars:01K1TS7X62NRH9CVEW68R6RBHD',
#  'cars:01K1TS7X628EWYWW571P8SQSVQ',
#  'cars:01K1TS7X62R1Q2EA03YNNPWJH0',
#  'cars:01K1TS7X625QP8N0WY3FRVGFNE',
#  'cars:01K1TS7X62T3SJHWGAKQPPAJJC',
#  'cars:01K1TS7X62ADF4QQFR9GRDY2TJ',
#  'cars:01K1TS7X62TBW542TQCS5RPCAZ',
#  'cars:01K1TS7X62BRPC1C0SE9JP00GF',
#  'cars:01K1TS7X62S2P8RX0YBBAVSQJ9',
#  'cars:01K1TS7X623ZFX748D6W220VYC',
#  'cars:01K1TS7X62SNCSJD8QVEB4YABR',
#  'cars:01K1TS7X62KT49V5ZCVRX34AJW',
#  'cars:01K1TS7X62QEY022S7GGTE9S3W',
#  'cars:01K1TS7X62KYCA2MRQ08S720FC',
#  'cars:01K1TS7X625H2V3FQB6X2PVEXR',
#  'cars:01K1TS7X62FQFAVZPVQYMMVHXT',
#  'cars:01K1TS7X624QVWBNQAEGFWADWE',
#  'cars:01K1TS7X62ZAR4C89NG6BB29GS',
#  'cars:01K1TS7X62EZF43QHAXEBSWMEN',
#  'cars:01K1TS7X62DPJXZYY08X49TVHY',
#  'cars:01K1TS7X62BCZDAK4A1WHQ8HN5',
#  'cars:01K1TS7X62FTYKCCA3H35ABTA9',
#  'cars:01K1TS7X62WMHG4HNNYQDQ91WT',
#  'cars:01K1TS7X62S81ZXR9DZFJ9QFS9',
#  'cars:01K1TS7X62VMNY3J7HBVHPZHZB',
#  'cars:01K1TS7X62ASWAD9R8ATM34NSY',
#  'cars:01K1TS7X62BVT2TTS6QBFQ32KC',
#  'cars:01K1TS7X625DPDGAXQWTRY5PJ9',
#  'cars:01K1TS7X62AC2KNNDZ0F7ES41K',
#  'cars:01K1TS7X62F0WCEF3G01KAH1DE',
#  'cars:01K1TS7X62260627YR31KMHM51',
#  'cars:01K1TS7X62FYWYHD23Y7G7C8X8',
#  'cars:01K1TS7X625RP2VHAZ0H201MMV',
#  'cars:01K1TS7X625C2ZW271YTK7KD7V',
#  'cars:01K1TS7X62QM2C8VVFXBZCQBE8',
#  'cars:01K1TS7X62N5AYJAJMKSZ2G51S',
#  'cars:01K1TS7X62MQ7719HE2AFA5JKY',
#  'cars:01K1TS7X6249DNKXA8130GP4EB',
#  'cars:01K1TS7X62TW3SRK4GF1SYS3SA',
#  'cars:01K1TS7X62WQRYAM7SPB9ZWR2T',
#  'cars:01K1TS7X62S2EH88Q8XFXR1THG',
#  'cars:01K1TS7X62ST06M79ZP5Y58GVB',
#  'cars:01K1TS7X62AEN73D2MG678EFHG',
#  'cars:01K1TS7X625TR51W8YEGYFWVKP',
#  'cars:01K1TS7X623XBGSTQZ1HDSQN5P',
#  'cars:01K1TS7X62RQ1J820CDG2GR55B',
#  'cars:01K1TS7X62VS4M0B7TWPZVTDJA',
#  'cars:01K1TS7X624QSG0DVHQ89S7505',
#  'cars:01K1TS7X62QPDG0086Z9E8ZRJN',
#  'cars:01K1TS7X62CZWWTXDK5R85H8B6',
#  'cars:01K1TS7X62F1R2F53VYEQ35171',
#  'cars:01K1TS7X628R377Y2KD6G5MPCD',
#  'cars:01K1TS7X62T5B2KW1W97N9RE42',
#  'cars:01K1TS7X62FSPQ1MS43JJ8KHC4',
#  'cars:01K1TS7X626VJ9WB44W4K6WBY2',
#  'cars:01K1TS7X62Y330KBHBE257H3T0',
#  'cars:01K1TS7X62BR291VJF6N691WZY',
#  'cars:01K1TS7X626TBY4GP2XZ3GHYDX',
#  'cars:01K1TS7X62K5JJANTQJDKDM6W8',
#  'cars:01K1TS7X627YGY1D8V6KWHMSR7',
#  'cars:01K1TS7X624XHQ4RE5MWSPEN59',
#  'cars:01K1TS7X6260S0Z13BWGJZY4Z8',
#  'cars:01K1TS7X62ZSWNWXTTXMX0FAEN',
#  'cars:01K1TS7X62SHV2MQ2F77THWVVK',
#  'cars:01K1TS7X62AXMPHFRV5XSPD53W',
#  'cars:01K1TS7X620NFK8F1CHDAG11XV',
#  'cars:01K1TS7X62ZB1Y6NFHXQ6ZFX1J',
#  'cars:01K1TS7X62GQHSWXXYJ6YCN2A2',
#  'cars:01K1TS7X62F9Q02SB4STYSXK16',
#  'cars:01K1TS7X62393B9TTX13JYNGK9',
#  'cars:01K1TS7X62W0QSQBMAYEXVATG1',
#  'cars:01K1TS7X6264EM4Q3WGTR3JXXX',
#  'cars:01K1TS7X62XQ25KMKCXYCWC7XC',
#  'cars:01K1TS7X62Y03NNM14WVA22QYM',
#  'cars:01K1TS7X63KP0E0JB83VV8W83G',
#  'cars:01K1TS7X63HDHGGBTJE2WYA9TT',
#  'cars:01K1TS7X63HH0N91JR0796SH6R',
#  'cars:01K1TS7X63VJABFHMC79B8DTWX',
#  'cars:01K1TS7X638TZBTTMJR219KTWE',
#  'cars:01K1TS7X635MRK3AS75RXPHW5R',
#  'cars:01K1TS7X63RQ6AM3QZ26ASFHKR',
#  'cars:01K1TS7X63X66M0KRFHA4JC73W',
#  'cars:01K1TS7X638T1J8ZXAFMBVM9G9',
#  'cars:01K1TS7X63AMAHKNE21GTFNVF3',
#  'cars:01K1TS7X63RE2EWGHHHJ6VWE4F',
#  'cars:01K1TS7X63VBT0GDTXY7YZRDZ3',
#  'cars:01K1TS7X639HN4JVNZ5FSPX5C8',
#  'cars:01K1TS7X63AC4TZKTKFY27FRTK',
#  'cars:01K1TS7X638Y7TZF6X3996HQ5P',
#  'cars:01K1TS7X63ZPZDQ971QYF53PEN',
#  'cars:01K1TS7X639G7GXDEW1XMQKTFK',
#  'cars:01K1TS7X63BNMRVTPB5ZED0P27',
#  'cars:01K1TS7X63JZVY4Z9W4FN9CWFN',
#  'cars:01K1TS7X63VNS706M9RSBW2158',
#  'cars:01K1TS7X63RE461JXM21QP511G',
#  'cars:01K1TS7X636H3ASB6SZ7NPK924',
#  'cars:01K1TS7X63M83400ZFFJXSZT2X',
#  'cars:01K1TS7X63RXRQV0NVWXGJSKWF',
#  'cars:01K1TS7X63A60B7A40RW9N5101',
#  'cars:01K1TS7X632VS1396PTTWC1JE6',
#  'cars:01K1TS7X63DM8X91E8E9D3X1GG',
#  'cars:01K1TS7X63Y5A4WSPH9FVYEJNY',
#  'cars:01K1TS7X63CCT4YYMCBRNS8YDK',
#  'cars:01K1TS7X63HSV4GYRVKWWPEGZR',
#  'cars:01K1TS7X63V2EM4E0SYGTMC0KN',
#  'cars:01K1TS7X634EM4E7E7CJ0Y7GFP',
#  'cars:01K1TS7X63Y3PPE24EYSP0PYC1',
#  'cars:01K1TS7X638JVFATP3J0CZJAD1',
#  'cars:01K1TS7X63CKRB2Q39K136YNRY',
#  'cars:01K1TS7X63JX93CXAV7135Z4MJ',
#  'cars:01K1TS7X63TTEHERZ5FAA0XVG8',
#  'cars:01K1TS7X63XNTVNESNZJ1P6ZS3',
#  'cars:01K1TS7X632MHW8CXESMS6FC09',
#  'cars:01K1TS7X63NRM81Q1K2P8A5V0B',
#  'cars:01K1TS7X63RXGVCJJQM0V24SS7',
#  'cars:01K1TS7X63N3QDE45E439RM9NQ',
#  'cars:01K1TS7X637YX360VHY4RFQ0GF',
#  'cars:01K1TS7X6302WZAZ766TC85V6Q',
#  'cars:01K1TS7X63HBE92QHJ3D26K8YY',
#  'cars:01K1TS7X63YAD85JNSEZPQBG5J',
#  'cars:01K1TS7X63GJTZ16CPWFAQ928N',
#  'cars:01K1TS7X63N1EN500G7PMXVRGS',
#  'cars:01K1TS7X63PH6SJKKSH3D2WVQ9',
#  'cars:01K1TS7X63Z8DFGFWW90GSWP3E',
#  'cars:01K1TS7X63BGY4Z0JQQ6MGK8PG',
#  'cars:01K1TS7X63X03YFP2YJ6Z8CGD8',
#  'cars:01K1TS7X639FY8SW1RN0JHE4T6',
#  'cars:01K1TS7X635TKHQXH101MP3SDP',
#  'cars:01K1TS7X634RMKMQGA1ENPF23F',
#  'cars:01K1TS7X63BJPM906BE8P20MKH',
#  'cars:01K1TS7X63575EE9KE52AZNAPJ',
#  'cars:01K1TS7X63YEHBTXCQJEA0AEYC',
#  'cars:01K1TS7X633ZRVFQMCG2ANQP8R',
#  'cars:01K1TS7X639JMNDV47Z3ZQMMVN',
#  'cars:01K1TS7X6353TSS7XMJCN6H9KS',
#  'cars:01K1TS7X633QRHHR2HJ0S4Z5VH',
#  'cars:01K1TS7X63PSJV2WV80X7YFB3F',
#  'cars:01K1TS7X630M74N4D7VMZ5ZKVR',
#  'cars:01K1TS7X63S2963YB9CC0N4WB0',
#  'cars:01K1TS7X63999803F4Z0Y3S1Z7',
#  'cars:01K1TS7X63NFRZK2DN50672XG1',
#  'cars:01K1TS7X63X4MEKJ7G5R7Y7ZVH',
#  'cars:01K1TS7X63RVQ744XDEQ68E9EB',
#  'cars:01K1TS7X63HA936SKPEB1T79WQ',
#  'cars:01K1TS7X63XZDPSVMX41WVYAXQ',
#  'cars:01K1TS7X6312H2387X6C4T8V7X',
#  'cars:01K1TS7X6375QHKHXF3STSFDFE',
#  'cars:01K1TS7X63SR8APZ006YNN1HM8',
#  'cars:01K1TS7X638ZPYYKKJ7SRNAWES',
#  'cars:01K1TS7X633S51GYYYNCEQAP9M',
#  'cars:01K1TS7X637CF83KWDG3K0V18H',
#  'cars:01K1TS7X63E42MXQEWVXHPVMG7',
#  'cars:01K1TS7X63NXKJ2VHK6SNPGPXP',
#  'cars:01K1TS7X63SJS5JR466G6GA762',
#  'cars:01K1TS7X63TBJ4H5YHC2FBV1F9',
#  'cars:01K1TS7X63473AX3TXN1QZ0K4Z',
#  'cars:01K1TS7X63H1P7KKAPA46BJJ03',
#  'cars:01K1TS7X63HZJHV0JBRVTKE7WE',
#  'cars:01K1TS7X63QE4Q70YEX839Z348',
#  'cars:01K1TS7X636KTN3BPYXKHQZFP1',
#  'cars:01K1TS7X638MQW19WSW11F66NR',
#  'cars:01K1TS7X63PGJBHS9Z6XM6S86D',
#  'cars:01K1TS7X633N3HP9556NW2866M',
#  'cars:01K1TS7X63HTN71B0QSQSY24SK',
#  'cars:01K1TS7X63C5YQT8H5J6V1N9W2',
#  'cars:01K1TS7X63QQXV72J9Z1VXQEVW',
#  'cars:01K1TS7X63SSPS35P0CS1FNQHV',
#  'cars:01K1TS7X63ED38X7WB8FYGNTNC',
#  'cars:01K1TS7X63NVZDN1NS2ZB3A9ZP',
#  'cars:01K1TS7X63NQMZP01DSB3X6VSK',
#  'cars:01K1TS7X639K9W897RGK3FMAE4',
#  'cars:01K1TS7X63DMEC58Y462H4KGFR',
#  'cars:01K1TS7X63KNSJJN72KPSEM1FS',
#  'cars:01K1TS7X636KFXCCAWFT9QM5NM',
#  'cars:01K1TS7X63E9GJVNE7CFNF2GFT',
#  'cars:01K1TS7X63T70TNXKD97MY2158',
#  'cars:01K1TS7X63A8AT0RCMX3CP0PC2',
#  'cars:01K1TS7X63SXRQ47792GYB16AJ',
#  'cars:01K1TS7X63QGAYRJV1FWQ4YQZV',
#  'cars:01K1TS7X63WTM860QH7WKVA6V6',
#  'cars:01K1TS7X639KXMW06XBBXHQYZN',
#  'cars:01K1TS7X635P0QMNHMCY5AYSJX',
#  'cars:01K1TS7X63P65VDWNYTC0WKR31',
#  'cars:01K1TS7X63PF4DJABC9CCFNK1N',
#  'cars:01K1TS7X63DQRH9EAEQ48YFW2P',
#  'cars:01K1TS7X63J96CSBKSH6VWRTA9',
#  'cars:01K1TS7X63PBW7KEB592TBSVG5',
#  'cars:01K1TS7X63MTYT8Z6PE356XKCE',
#  'cars:01K1TS7X63GGFW25KJD47GTEVX',
#  'cars:01K1TS7X63YJZQX0H9R9VA9MDH',
#  'cars:01K1TS7X63J3TFRWZ6FR3JBDYW',
#  'cars:01K1TS7X63C46A8KH09MZ5NV6Q',
#  'cars:01K1TS7X63111FVE2QZJPJDERZ',
#  'cars:01K1TS7X63WQ0B9JWJ5BEVHPA5',
#  'cars:01K1TS7X63AFPXNN5SWX4C6JG0',
#  'cars:01K1TS7X63HHB5NXXNAP8J0KH3',
#  'cars:01K1TS7X63M7HE59KP5QPJ2E81',
#  'cars:01K1TS7X63069KP13P047FWKN5',
#  'cars:01K1TS7X6313F85J40M1PPTS7Q',
#  'cars:01K1TS7X63TZJFNQBJZE521KC5',
#  'cars:01K1TS7X6369ZFQVKGFAQHE7PQ',
#  'cars:01K1TS7X630ZZEBNWKF3B6NCVC',
#  'cars:01K1TS7X63BXQTMNEBJC6FQ7Q1',
#  'cars:01K1TS7X63HHK2ZJ1CRH8FX83V',
#  'cars:01K1TS7X63WVVD3XKQ0S13EAC8',
#  'cars:01K1TS7X63V7A6QARGXD2KHK7Q',
#  'cars:01K1TS7X63361TWAMWW311AW0E',
#  'cars:01K1TS7X63P07TC0P1BKB24XZW',
#  'cars:01K1TS7X63QR6JFG7KJZS7QVR0',
#  'cars:01K1TS7X63JS00FCX8XY4YFC1W',
#  'cars:01K1TS7X63A4PXVXPJ1SAKX6BH',
#  'cars:01K1TS7X63TQNWFM9Z7TVB9Y2R',
#  'cars:01K1TS7X63R05J47BB2B15TRW7',
#  'cars:01K1TS7X63AGVPSMZSK7AR004J',
#  'cars:01K1TS7X63JWV8R1JXMCVTH3HB',
#  'cars:01K1TS7X635MF2367MDAJXWD2M',
#  'cars:01K1TS7X636P879KYZ0KWPFZ66',
#  'cars:01K1TS7X63BYTFR4NEMQ0MQ45M',
#  'cars:01K1TS7X63RWNVC2WYBCG5PJ5A',
#  'cars:01K1TS7X63P2M8PSAHVPEF7HGK',
#  'cars:01K1TS7X63E9BRAPAP2YG3H6Z5',
#  'cars:01K1TS7X63X2RKF7BKY75QET1S',
#  'cars:01K1TS7X63YTSF3M7MYKVC2XXG',
#  'cars:01K1TS7X634DZRRB53863QPCJ4',
#  'cars:01K1TS7X63EDZMCP37C5A4TZQC',
#  'cars:01K1TS7X63C0DS61HXMA3V9HQB',
#  'cars:01K1TS7X63J7AJ5TCNWA886ZKT',
#  'cars:01K1TS7X63FWJPYDGHWVJTW292',
#  'cars:01K1TS7X63K7SK3DQAYEZV1JZK',
#  'cars:01K1TS7X63X7RQ89HC45VAMAR1',
#  'cars:01K1TS7X63GDF2F5TEAJK21GRE',
#  'cars:01K1TS7X63M85SHY3T9AXYPVJK',
#  'cars:01K1TS7X63A948AYT14K0MGM1K',
#  'cars:01K1TS7X63KAYCZRZ565S5MZJB',
#  'cars:01K1TS7X63JA852DNY2X5B71RE',
#  'cars:01K1TS7X63BXGP8ZB8H3GSG9VJ',
#  'cars:01K1TS7X63RGWGZC4D1302YPY8',
#  'cars:01K1TS7X63FZZBAPRGR5HZJ6MP',
#  'cars:01K1TS7X6317C1HH10XX23J771',
#  'cars:01K1TS7X63862KY6NPQMX2CCBM',
#  'cars:01K1TS7X63GWZXPS2EYGYZ6YB8',
#  'cars:01K1TS7X63066Y7C8HP9XNF8WY',
#  'cars:01K1TS7X639HN142GRXTPQ5SAW',
#  'cars:01K1TS7X6319HVYNTQZR3HPVQ9',
#  'cars:01K1TS7X632XX7DJN0H8MN8TVW',
#  'cars:01K1TS7X63HVB614T3YRKKY6MM',
#  'cars:01K1TS7X63HSVNGQC1EYV0QBXC',
#  'cars:01K1TS7X63NC7VBBMMFTQD3D63',
#  'cars:01K1TS7X638BNGTW3AZRSBSW9A',
#  'cars:01K1TS7X63KWSYEXCR9VMPJ402',
#  'cars:01K1TS7X63XD1KZKM3PXGZCCAK',
#  'cars:01K1TS7X6301ECTKT8ZEET33FP',
#  'cars:01K1TS7X639N7Q6HY2DTRGA5RM',
#  'cars:01K1TS7X63ERD7GQ8ZGHY53269',
#  'cars:01K1TS7X6379KC40HA0KZCWX1P',
#  'cars:01K1TS7X63NFZN5387A761ZZRS',
#  'cars:01K1TS7X63T0W2HMPRCWPMDZV2',
#  'cars:01K1TS7X635YRNNQ0XCT7RFP5J',
#  'cars:01K1TS7X6346G0WN1NZ4J10FVG',
#  'cars:01K1TS7X6371197S36YZ7XYY2S',
#  'cars:01K1TS7X63MBJEJP2E918ZDHJ6',
#  'cars:01K1TS7X63CEY6RPRHWEN7FTEX',
#  'cars:01K1TS7X63JDFNJXFNZG13F632',
#  'cars:01K1TS7X63JEQSWXN0QMYQ0AXK',
#  'cars:01K1TS7X63XB6SHDTBR7175Q9Q',
#  'cars:01K1TS7X64QEXFATYXCXFTB16G',
#  'cars:01K1TS7X647DKTSF53D1MSEXKX',
#  'cars:01K1TS7X64CBEAWBGWD8P9ZBSB',
#  'cars:01K1TS7X644PST731CSE6NGK8C',
#  'cars:01K1TS7X64NHXDMQ41B1VN7HSA',
#  'cars:01K1TS7X6477WQ9YSB4Z3YAJYH',
#  'cars:01K1TS7X640BHYXGVE95B15HET',
#  'cars:01K1TS7X641CBG55B8VX5QP302',
#  'cars:01K1TS7X642Z5NW15CX1W2XFE5',
#  'cars:01K1TS7X64RSWFHG0QVM4DVB6M',
#  'cars:01K1TS7X64V3X4MV9791CXRXWF',
#  'cars:01K1TS7X64C3Z4C1PEB42GCP21',
#  'cars:01K1TS7X648ZT1351BX61MK9ND',
#  'cars:01K1TS7X64KHN896HZ3KDQ733M',
#  'cars:01K1TS7X64ZQNTZ5JGSDNK35Q9',
#  'cars:01K1TS7X64TASRZYT28RFGHQQE']

# %% [markdown]
# # Check index created successfully

# %%
index.info()["num_docs"]
# Out:
# 464

# %% [markdown]
# # Review search study config
#
# - index_name should point to index created above
# - qrels and queries should point to the queries and set of labeled queries under test
# - search methods should match with the custom methods defined below
# - embedding_model should match with the one used to create the index

# %%
from redis_retrieval_optimizer.utils import load_search_study_config

search_study_config = load_search_study_config("search_study_config.yaml")
search_study_config
# Out:
# SearchStudyConfig(study_id='test-search-study', index_name='cars', qrels='../resources/cars/car_qrels.json', queries='../resources/cars/car_queries.json', search_methods=['base_vector', 'pre_filter_vector'], ret_k=6, embedding_model=EmbeddingModel(type='hf', model='sentence-transformers/all-mpnet-base-v2', dim=768, embedding_cache_name='vec-cache', dtype='float32'))

# %% [markdown]
# # Define search methods for search study
#
# A search method can be anything as long as it takes a `SearchMethodInput` and returns a `SearchMethodOutput`. Below we will compare a basic vector search to a vector search with a pre-filter.

# %%
from ranx import Run
from redis_retrieval_optimizer.search_methods.base import run_search_w_time
from redisvl.query import VectorQuery
from redisvl.query.filter import Tag

from redis_retrieval_optimizer.schema import SearchMethodInput, SearchMethodOutput
from redis_retrieval_optimizer.search_methods.vector import make_score_dict_vec

def vector_query(query_info, num_results: int, emb_model) -> VectorQuery:
    vector = emb_model.embed(query_info["query"], as_buffer=True)

    return VectorQuery(
        vector=vector,
        vector_field_name="vector",
        num_results=num_results,
        return_fields=["item_id", "make", "model", "text"],  # update to read from env maybe?
    )

def pre_filter_query(query_info, num_results, emb_model) -> VectorQuery:
    vec = emb_model.embed(query_info["query"])
    make = query_info["query_metadata"]["make"]
    model = query_info["query_metadata"]["model"]

    filter = (Tag("make") == make) & (Tag("model") == model)

    # Create a vector query
    query = VectorQuery(
        vector=vec,
        vector_field_name="vector",
        num_results=num_results,
        filter_expression=filter,
        return_fields=["item_id", "make", "model", "text"]
    )

    return query

def gather_pre_filter_results(search_method_input: SearchMethodInput) -> SearchMethodOutput:
    redis_res_vector = {}

    for key in search_method_input.raw_queries:
        query_info = search_method_input.raw_queries[key]
        query = pre_filter_query(query_info, 10, search_method_input.emb_model)
        res = run_search_w_time(
            search_method_input.index, query, search_method_input.query_metrics
        )
        score_dict = make_score_dict_vec(res, id_field_name="item_id")

        redis_res_vector[key] = score_dict

    return SearchMethodOutput(
        run=Run(redis_res_vector),
        query_metrics=search_method_input.query_metrics,
    )


def gather_vector_results(search_method_input: SearchMethodInput) -> SearchMethodOutput:
    redis_res_vector = {}

    for key in search_method_input.raw_queries:
        query_info = search_method_input.raw_queries[key]
        vec_query = vector_query(query_info, 10, search_method_input.emb_model)
        res = run_search_w_time(
            search_method_input.index, vec_query, search_method_input.query_metrics
        )
        score_dict = make_score_dict_vec(res, id_field_name="item_id")
        redis_res_vector[key] = score_dict
        
    return SearchMethodOutput(
        run=Run(redis_res_vector),
        query_metrics=search_method_input.query_metrics,
    )

# %% [markdown]
# # Run the search study

# %%
from redis_retrieval_optimizer.search_study import run_search_study

# Note: must match with what's in the search_study_config.
SEARCH_METHOD_MAP = {
    "base_vector": gather_vector_results,
    "pre_filter_vector": gather_pre_filter_results
}

metrics = run_search_study(
    config_path="search_study_config.yaml",
    redis_url=redis_url,
    search_method_map=SEARCH_METHOD_MAP
)
# Out:
# Connecting to existing index: cars
# Connected to index: cars with 464 objects
# 10:57:45 sentence_transformers.SentenceTransformer INFO   Use pytorch device_name: mps
# 10:57:45 sentence_transformers.SentenceTransformer INFO   Load pretrained SentenceTransformer: sentence-transformers/all-mpnet-base-v2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Running search method: base_vector
# Running search method: pre_filter_vector

# %%
metrics
# Out:
#        search_method total_indexing_time  total_memory_mb  avg_query_time  \
# 0        base_vector   130.3800048828125         4.008235        0.003192
# 1  pre_filter_vector   130.3800048828125         4.008235        0.001466
#
#    recall      ndcg        f1  precision  ret_k
# 0   0.925  0.801212  0.350375       0.23      6
# 1   1.000  0.938926  0.381327       0.25      6
