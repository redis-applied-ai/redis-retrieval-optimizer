# %%
import sys
import os

# Add the parent directory to the Python path to get optimize module
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../..')))

import examples.beir.helpers as beir_helpers
from beir.retrieval.evaluation import EvaluateRetrieval
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       4 # Add the parent directory to the Python path to get optimize module
#       5 sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../..')))
# ----> 7 import examples.beir.helpers as beir_helpers
#       8 from beir.retrieval.evaluation import EvaluateRetrieval
#
# ModuleNotFoundError: No module named 'examples.beir'

# %%
corpus, queries, qrels = eval_beir_helpers.get_beir_dataset(dataset)
corpus_data = eval_beir_helpers.process_corpus(corpus, emb_model=emb_model)
